# %%
# example runs but way too many,  just need DOIs and titles, maybe PI
from datetime import datetime
import sys, re, fileinput
import json
import requests  # http://docs.python-requests.org/en/master/
import pyDataverse
from pyDataverse.api import Api
# establish connection
# example runs but way too many,  just need DOIs and titles, maybe PI
import urllib
from urllib.parse import urlparse

#outfile = open('D:\work-related\pyDataverse\dvOut2.txt', 'w')
with open('D:\work-related\pyDataverse\dvOut.csv', "w", encoding="utf-8") as outfile:

    #base = 'https://test.dataverse.ucla.edu'
    base = 'https://dataverse.ucla.edu/'
    #base = 'https://dataverse.harvard.edu/dataverse/ssda_ucla'
    print(base)
    rows = 10
    start = 0
    page = 1
    condition = True # emulate do-while
    #outfile = open('D:\work-related\pyDataverse\dataverse-info.csv', 'w')
    while (condition):
        url = base + '/api/search?q=*' + "&start=" + str(start)
        print(url)
        data = json.load(urllib.request.urlopen(url))   
        print(data)
        total = data['data']['total_count']
        #print ("=== Page", page, "===")
        print ("start:", start, " total:", total)
        for i in data['data']['items']:
            if (i['type']) != 'file':
                #print (i['name'] + "," + i['type'])
                line=("\"" + i['name'] + "\"" + "," + i['type']+ "," + i['url'])
                print(line)
                outfile.write(line)
                outfile.write("\n")
    
        start = start + rows
        page += 1
        condition = start < total

    outfile.close()
# Out:
# https://dataverse.ucla.edu/
# https://dataverse.ucla.edu//api/search?q=*&start=0
# {'status': 'OK', 'data': {'q': '*', 'total_count': 5067, 'start': 0, 'spelling_alternatives': {}, 'items': [{'name': 'Anna Urbanowicz-Krowacka and Fiber Art', 'type': 'dataset', 'url': 'https://doi.org/10.25346/S6/BSIDAA', 'global_id': 'doi:10.25346/S6/BSIDAA', 'description': "Article from Woman's Art Journal, Vol. 8, No. 2 (Autumn, 1987 - Winter, 1988), pp. 39-44. Stable URL: http://www.jstor.org/stable/1358165 Accessed: 12-06-2018 18:33 UTC File accessible to UCLA Faculty/Staff/Students only. Please log on to download.", 'published_at': '2019-09-12T21:24:43Z', 'publisher': 'UCLA Library Materials', 'citationHtml': 'Batorska, Daunta, 2019, "Anna Urbanowicz-Krowacka and Fiber Art", <a href="https://doi.org/10.25346/S6/BSIDAA" target="_blank">https://doi.org/10.25346/S6/BSIDAA</a>, UCLA Dataverse, V1', 'identifier_of_dataverse': 'ucla-library-restricted', 'name_of_dataverse': 'UCLA Library Materials', 'citation': 'Batorska, Daunta, 2019, "Anna Urbanowicz-Krowacka and Fiber Art", https://doi.org/10.25346/S6/BSIDAA, UCLA Dataverse, V1', 'storageIdentifier': 's3://10.25346/S6/BSIDAA', 'subjects': ['Arts and Humanities'], 'fileCount': 1, 'versionId': 1056, 'versionState': 'RELEASED', 'majorVersion': 1, 'minorVersion': 2, 'createdAt': '2019-09-12T21:24:35Z', 'updatedAt': '2019-09-17T20:31:09Z', 'contacts': [{'name': 'JAMISON, JINA', 'affiliation': 'University of California, Los Angeles'}], 'publications': [{'citation': "Woman's Art Journal, Vol. 8, No. 2 (Autumn, 1987 - Winter, 1988), pp. 39-44"}], 'geographicCoverage': [{'country': ''}], 'authors': ['Batorska, Daunta']}, {'name': 'WomansArtJournal-AnnaUK.pdf', 'type': 'file', 'url': 'https://dataverse.ucla.edu/api/access/datafile/8223', 'file_id': '8223', 'description': 'Acrobat Pdf format', 'published_at': '2019-09-12T21:24:43Z', 'file_type': 'Adobe PDF', 'file_content_type': 'application/pdf', 'size_in_bytes': 1601912, 'md5': '735e9a6161568cfff4a7728ec59ae158', 'checksum': {'type': 'MD5', 'value': '735e9a6161568cfff4a7728ec59ae158'}, 'file_persistent_id': 'doi:10.25346/S6/BSIDAA/6EHDMU', 'dataset_name': 'Anna Urbanowicz-Krowacka and Fiber Art', 'dataset_id': '8222', 'dataset_persistent_id': 'doi:10.25346/S6/BSIDAA', 'dataset_citation': 'Batorska, Daunta, 2019, "Anna Urbanowicz-Krowacka and Fiber Art", https://doi.org/10.25346/S6/BSIDAA, UCLA Dataverse, V1'}, {'name': '106右派处理', 'type': 'dataset', 'url': 'https://doi.org/10.25346/S6/P64ZOJ', 'global_id': 'doi:10.25346/S6/P64ZOJ', 'description': 'Test preview function, view-pdf on EAL documents', 'published_at': '2020-01-11T00:26:41Z', 'publisher': 'UCLA Library Materials', 'citationHtml': 'JAMISON, JINA, 2020, "106&#21491;&#27966;&#22788;&#29702;", <a href="https://doi.org/10.25346/S6/P64ZOJ" target="_blank">https://doi.org/10.25346/S6/P64ZOJ</a>, UCLA Dataverse, V2', 'identifier_of_dataverse': 'ucla-library-restricted', 'name_of_dataverse': 'UCLA Library Materials', 'citation': 'JAMISON, JINA, 2020, "106右派处理", https://doi.org/10.25346/S6/P64ZOJ, UCLA Dataverse, V2', 'storageIdentifier': 's3://10.25346/S6/P64ZOJ', 'subjects': ['Other'], 'fileCount': 1, 'versionId': 1067, 'versionState': 'RELEASED', 'majorVersion': 2, 'minorVersion': 0, 'createdAt': '2020-01-11T00:23:19Z', 'updatedAt': '2020-01-11T00:26:41Z', 'contacts': [{'name': 'JAMISON, JINA', 'affiliation': 'University of California, Los Angeles'}, {'name': 'Chen, Su', 'affiliation': 'University of California, Los Angeles'}], 'authors': ['JAMISON, JINA']}, {'name': '106右派处理.pdf', 'type': 'file', 'url': 'https://dataverse.ucla.edu/api/access/datafile/19551', 'file_id': '19551', 'published_at': '2020-01-11T00:26:41Z', 'file_type': 'Adobe PDF', 'file_content_type': 'application/pdf', 'size_in_bytes': 19214428, 'md5': 'c04d1eaee1e2b18053477c0c02519eb0', 'checksum': {'type': 'MD5', 'value': 'c04d1eaee1e2b18053477c0c02519eb0'}, 'file_persistent_id': 'doi:10.25346/S6/P64ZOJ/1KC0VQ', 'dataset_name': '106右派处理', 'dataset_id': '19550', 'dataset_persistent_id': 'doi:10.25346/S6/P64ZOJ', ' ...
# start: 0  total: 5067
# "Anna Urbanowicz-Krowacka and Fiber Art",dataset,https://doi.org/10.25346/S6/BSIDAA
# "106右派处理",dataset,https://doi.org/10.25346/S6/P64ZOJ
# "Karakax Valley Site 4 - Cosmogenic dating results",dataset,https://doi.org/10.25346/S6/LXHDMJ
# "Karakax Valley Site 1 - Pleiades Digital Elevation Model",dataset,https://doi.org/10.25346/S6/MSSC65
# https://dataverse.ucla.edu//api/search?q=*&start=10
# {'status': 'OK', 'data': {'q': '*', 'total_count': 5067, 'start': 10, 'spelling_alternatives': {}, 'items': [{'name': 'atf_site1_pleiades_dem.tif.aux.xml', 'type': 'file', 'url': 'https://dataverse.ucla.edu/api/access/datafile/19556', 'file_id': '19556', 'published_at': '2020-01-27T23:11:47Z', 'file_type': 'XML', 'file_content_type': 'text/xml', 'size_in_bytes': 3670, 'md5': '3ad0f541f619ff6c66d1b0eee29198a5', 'checksum': {'type': 'MD5', 'value': '3ad0f541f619ff6c66d1b0eee29198a5'}, 'file_persistent_id': 'doi:10.25346/S6/MSSC65/CQFYKC', 'dataset_name': 'Karakax Valley Site 1 - Pleiades Digital Elevation Model', 'dataset_id': '19555', 'dataset_persistent_id': 'doi:10.25346/S6/MSSC65', 'dataset_citation': 'PELTZER, GILLES, 2020, "Karakax Valley Site 1 - Pleiades Digital Elevation Model", https://doi.org/10.25346/S6/MSSC65, UCLA Dataverse, V1'}, {'name': 'D570510-gx67-2-110-22-34', 'type': 'dataset', 'url': 'https://doi.org/10.25346/S6/KPBI8X', 'global_id': 'doi:10.25346/S6/KPBI8X', 'description': 'Test file viewer, view pdf', 'published_at': '2020-01-11T00:30:34Z', 'publisher': 'UCLA Library Materials', 'citationHtml': 'JAMISON, JINA, 2020, "D570510-gx67-2-110-22-34", <a href="https://doi.org/10.25346/S6/KPBI8X" target="_blank">https://doi.org/10.25346/S6/KPBI8X</a>, UCLA Dataverse, V2', 'identifier_of_dataverse': 'ucla-library-restricted', 'name_of_dataverse': 'UCLA Library Materials', 'citation': 'JAMISON, JINA, 2020, "D570510-gx67-2-110-22-34", https://doi.org/10.25346/S6/KPBI8X, UCLA Dataverse, V2', 'storageIdentifier': 's3://10.25346/S6/KPBI8X', 'subjects': ['Other'], 'fileCount': 1, 'versionId': 1070, 'versionState': 'RELEASED', 'majorVersion': 2, 'minorVersion': 1, 'createdAt': '2020-01-11T00:29:02Z', 'updatedAt': '2020-01-11T00:31:18Z', 'contacts': [{'name': 'JAMISON, JINA', 'affiliation': 'University of California, Los Angeles'}, {'name': 'Chen, Su', 'affiliation': 'University of California, Los Angeles'}], 'authors': ['JAMISON, JINA']}, {'name': 'D570510,gx67-2-110,22-34.pdf', 'type': 'file', 'url': 'https://dataverse.ucla.edu/api/access/datafile/19553', 'file_id': '19553', 'published_at': '2020-01-11T00:30:34Z', 'file_type': 'Adobe PDF', 'file_content_type': 'application/pdf', 'size_in_bytes': 2945074, 'md5': '264019ab64121f956d8450696a976d6d', 'checksum': {'type': 'MD5', 'value': '264019ab64121f956d8450696a976d6d'}, 'file_persistent_id': 'doi:10.25346/S6/KPBI8X/3FAYJG', 'dataset_name': 'D570510-gx67-2-110-22-34', 'dataset_id': '19552', 'dataset_persistent_id': 'doi:10.25346/S6/KPBI8X', 'dataset_citation': 'JAMISON, JINA, 2020, "D570510-gx67-2-110-22-34", https://doi.org/10.25346/S6/KPBI8X, UCLA Dataverse, V2'}, {'name': 'UCLA Registrar Enrollment Data, Winter 1999 - Spring 2020', 'type': 'dataset', 'url': 'https://doi.org/10.25346/S6/LRV0ES', 'global_id': 'doi:10.25346/S6/LRV0ES', 'description': "Enrollment data scraped from the UCLA Registrar's publicly available Schedule of Classes. Details about the data and scraper are linked below: Exploring Enrollment: Methodology Scraping Enrollment Data From the UCLA Registrar, Part One Scraping Enrollment Data From the UCLA Registrar, Part Two", 'published_at': '2020-03-18T17:45:38Z', 'publisher': 'NATHAN SMITH Dataverse', 'citationHtml': 'Smith, Nathan, 2020, "UCLA Registrar Enrollment Data, Winter 1999 - Spring 2020", <a href="https://doi.org/10.25346/S6/LRV0ES" target="_blank">https://doi.org/10.25346/S6/LRV0ES</a>, UCLA Dataverse, V1', 'identifier_of_dataverse': 'nathan-smith', 'name_of_dataverse': 'NATHAN SMITH Dataverse', 'citation': 'Smith, Nathan, 2020, "UCLA Registrar Enrollment Data, Winter 1999 - Spring 2020", https://doi.org/10.25346/S6/LRV0ES, UCLA Dataverse, V1', 'storageIdentifier': 's3://10.25346/S6/LRV0ES', 'subjects': ['Social Sciences'], 'fileCount': 1, 'versionId': 1093, 'versionState': 'RELEASED', 'majorVersion': 1, 'minorVersion': 0, 'createdAt': '2020-03-16T22:18:42Z', 'updatedAt': '2020-03-18T17:45:38Z', 'contacts': [{'name': 'Smith, Nathan', 'affilia ...
# start: 10  total: 5067
# "D570510-gx67-2-110-22-34",dataset,https://doi.org/10.25346/S6/KPBI8X
# "UCLA Registrar Enrollment Data, Winter 1999 - Spring 2020",dataset,https://doi.org/10.25346/S6/LRV0ES
# "Karakax Valley Site 1 - OSL dating results",dataset,https://doi.org/10.25346/S6/NI2QFL
# "Gapminder Data",dataset,https://doi.org/10.25346/S6/WFC3KG
# https://dataverse.ucla.edu//api/search?q=*&start=20
# {'status': 'OK', 'data': {'q': '*', 'total_count': 5067, 'start': 20, 'spelling_alternatives': {}, 'items': [{'name': 'gapminder_wide.tab', 'type': 'file', 'url': 'https://dataverse.ucla.edu/api/access/datafile/20391', 'file_id': '20391', 'description': 'gapminder data for workshops', 'published_at': '2020-04-17T20:47:00Z', 'file_type': 'Tab-Delimited', 'file_content_type': 'text/tab-separated-values', 'size_in_bytes': 48544, 'md5': '8a1f05738b5df75ce6cf2f2ede0c4d70', 'checksum': {'type': 'MD5', 'value': '8a1f05738b5df75ce6cf2f2ede0c4d70'}, 'unf': 'UNF:6:sC8v9sQ85iIpVveAGxfWig==', 'file_persistent_id': 'doi:10.25346/S6/WFC3KG/D5DTLN', 'dataset_name': 'Gapminder Data', 'dataset_id': '20389', 'dataset_persistent_id': 'doi:10.25346/S6/WFC3KG', 'dataset_citation': 'Rosling, Hans, 2020, "Gapminder Data", https://doi.org/10.25346/S6/WFC3KG, UCLA Dataverse, V4, UNF:6:NEKJa+hemgnpmRHJMFVKKA== [fileUNF]'}, {'name': 'index.ipynb', 'type': 'file', 'url': 'https://dataverse.ucla.edu/api/access/datafile/20459', 'file_id': '20459', 'description': 'Used for mybinder test', 'published_at': '2020-05-01T23:27:50Z', 'file_type': 'Jupyter Notebook', 'file_content_type': 'application/x-ipynb+json', 'size_in_bytes': 251898, 'md5': '36aefe47e7473843ed79641f39dd014d', 'checksum': {'type': 'MD5', 'value': '36aefe47e7473843ed79641f39dd014d'}, 'file_persistent_id': 'doi:10.25346/S6/WFC3KG/UVVMVI', 'dataset_name': 'Gapminder Data', 'dataset_id': '20389', 'dataset_persistent_id': 'doi:10.25346/S6/WFC3KG', 'dataset_citation': 'Rosling, Hans, 2020, "Gapminder Data", https://doi.org/10.25346/S6/WFC3KG, UCLA Dataverse, V4, UNF:6:NEKJa+hemgnpmRHJMFVKKA== [fileUNF]'}, {'name': 'install.R', 'type': 'file', 'url': 'https://dataverse.ucla.edu/api/access/datafile/20458', 'file_id': '20458', 'description': 'Code for mybinder test', 'published_at': '2020-05-01T23:15:38Z', 'file_type': 'R Syntax', 'file_content_type': 'type/x-r-syntax', 'size_in_bytes': 153, 'md5': '9698d87f82702dd4ef5a0e45c9facaff', 'checksum': {'type': 'MD5', 'value': '9698d87f82702dd4ef5a0e45c9facaff'}, 'file_persistent_id': 'doi:10.25346/S6/WFC3KG/JCF0A9', 'dataset_name': 'Gapminder Data', 'dataset_id': '20389', 'dataset_persistent_id': 'doi:10.25346/S6/WFC3KG', 'dataset_citation': 'Rosling, Hans, 2020, "Gapminder Data", https://doi.org/10.25346/S6/WFC3KG, UCLA Dataverse, V4, UNF:6:NEKJa+hemgnpmRHJMFVKKA== [fileUNF]'}, {'name': 'runtime.txt', 'type': 'file', 'url': 'https://dataverse.ucla.edu/api/access/datafile/20457', 'file_id': '20457', 'description': 'code for mybinder test', 'published_at': '2020-05-01T23:15:38Z', 'file_type': 'Plain Text', 'file_content_type': 'text/plain', 'size_in_bytes': 18, 'md5': '023dd9ee9b5b8ca1d680479d4cf523cd', 'checksum': {'type': 'MD5', 'value': '023dd9ee9b5b8ca1d680479d4cf523cd'}, 'file_persistent_id': 'doi:10.25346/S6/WFC3KG/C1KDWD', 'dataset_name': 'Gapminder Data', 'dataset_id': '20389', 'dataset_persistent_id': 'doi:10.25346/S6/WFC3KG', 'dataset_citation': 'Rosling, Hans, 2020, "Gapminder Data", https://doi.org/10.25346/S6/WFC3KG, UCLA Dataverse, V4, UNF:6:NEKJa+hemgnpmRHJMFVKKA== [fileUNF]'}, {'name': 'City of Los Angeles: Arrest Data from 2010 to Present', 'type': 'dataset', 'url': 'https://doi.org/10.25346/S6/DE95RT', 'global_id': 'doi:10.25346/S6/DE95RT', 'description': 'This dataset reflects arrest incidents in the City of Los Angeles dating back to 2010. This data is transcribed from original arrest reports that are typed on paper and therefore there may be some inaccuracies within the data. Some location fields with missing data are noted as (0.0000°, 0.0000°). Address fields are only provided to the nearest hundred block in order to maintain privacy. This data is as accurate as the data in the database. Please note questions or concerns in the comments. This data was further prepared by the Million Dollar Hoods group to recategorize certain variables. The UCLA Data Science Center also modified the data, changing variable names to meet R conventions an ...
# start: 20  total: 5067
# "City of Los Angeles: Arrest Data from 2010 to Present",dataset,https://doi.org/10.25346/S6/DE95RT
# "Tim Dennis Dataverse",dataverse,https://dataverse.ucla.edu/dataverse/timdennis
# https://dataverse.ucla.edu//api/search?q=*&start=30
# {'status': 'OK', 'data': {'q': '*', 'total_count': 5067, 'start': 30, 'spelling_alternatives': {}, 'items': [{'name': 'Spring 2020 R Workshop', 'type': 'dataset', 'url': 'https://doi.org/10.25346/S6/ZJKUAC', 'global_id': 'doi:10.25346/S6/ZJKUAC', 'description': 'Data Science Center remote workshops', 'published_at': '2020-05-15T15:52:00Z', 'publisher': 'UCLA Data Science Center', 'citationHtml': 'Data Science Center; Jamison, Jamie; Allen, Kristian; Phan, Leigh, 2020, "Spring 2020 R Workshop", <a href="https://doi.org/10.25346/S6/ZJKUAC" target="_blank">https://doi.org/10.25346/S6/ZJKUAC</a>, UCLA Dataverse, V9', 'identifier_of_dataverse': 'dsc', 'name_of_dataverse': 'UCLA Data Science Center', 'citation': 'Data Science Center; Jamison, Jamie; Allen, Kristian; Phan, Leigh, 2020, "Spring 2020 R Workshop", https://doi.org/10.25346/S6/ZJKUAC, UCLA Dataverse, V9', 'storageIdentifier': 's3://10.25346/S6/ZJKUAC', 'subjects': ['Computer and Information Science'], 'fileCount': 6, 'versionId': 1126, 'versionState': 'RELEASED', 'majorVersion': 9, 'minorVersion': 0, 'createdAt': '2020-04-20T18:19:52Z', 'updatedAt': '2020-05-23T16:50:39Z', 'contacts': [{'name': 'Data Science Center', 'affiliation': 'University of California, Los Angeles'}], 'publications': [{'citation': 'Jamie Jamison, Kristian Allen, Leigh Phan, Tim Dennis, (2020, April). ucla-data-archive/2020-ucla-r: UCLA R Workshop Series - Spring 2020, April-May 2020.', 'url': 'https://github.com/ucla-data-archive/2020-ucla-r'}], 'authors': ['Data Science Center', 'Jamison, Jamie', 'Allen, Kristian', 'Phan, Leigh']}, {'name': '02-2020-04-17_data-cleaning-r-classnotes.pdf', 'type': 'file', 'url': 'https://dataverse.ucla.edu/api/access/datafile/20453', 'file_id': '20453', 'description': 'Class notes, outline for workshop', 'published_at': '2020-04-22T17:52:16Z', 'file_type': 'Adobe PDF', 'file_content_type': 'application/pdf', 'size_in_bytes': 112311, 'md5': 'f576ea16978896dc469941e008592501', 'checksum': {'type': 'MD5', 'value': 'f576ea16978896dc469941e008592501'}, 'file_persistent_id': 'doi:10.25346/S6/ZJKUAC/NB4ZPS', 'dataset_name': 'Spring 2020 R Workshop', 'dataset_id': '20392', 'dataset_persistent_id': 'doi:10.25346/S6/ZJKUAC', 'dataset_citation': 'Data Science Center; Jamison, Jamie; Allen, Kristian; Phan, Leigh, 2020, "Spring 2020 R Workshop", https://doi.org/10.25346/S6/ZJKUAC, UCLA Dataverse, V9'}, {'name': '2020-04-10_intro-r.mp4', 'type': 'file', 'url': 'https://dataverse.ucla.edu/api/access/datafile/20394', 'file_id': '20394', 'description': 'Video recording of Intro to R taken on April 10, 2020. ', 'published_at': '2020-04-21T02:06:50Z', 'file_type': 'MPEG-4 Video', 'file_content_type': 'video/mp4', 'size_in_bytes': 270922611, 'md5': 'd5b34a3917c3c7ea65ca15293d7bc000', 'checksum': {'type': 'MD5', 'value': 'd5b34a3917c3c7ea65ca15293d7bc000'}, 'file_persistent_id': 'doi:10.25346/S6/ZJKUAC/D5CNHY', 'dataset_name': 'Spring 2020 R Workshop', 'dataset_id': '20392', 'dataset_persistent_id': 'doi:10.25346/S6/ZJKUAC', 'dataset_citation': 'Data Science Center; Jamison, Jamie; Allen, Kristian; Phan, Leigh, 2020, "Spring 2020 R Workshop", https://doi.org/10.25346/S6/ZJKUAC, UCLA Dataverse, V9'}, {'name': '2020-04-17_data-cleaning-r.mp4', 'type': 'file', 'url': 'https://dataverse.ucla.edu/api/access/datafile/20397', 'file_id': '20397', 'description': 'Workshop on using R for data cleaning. ', 'published_at': '2020-04-21T15:03:18Z', 'file_type': 'MPEG-4 Video', 'file_content_type': 'video/mp4', 'size_in_bytes': 426289310, 'md5': '2fb82759d1a2fecc0b8984a85456d1af', 'checksum': {'type': 'MD5', 'value': '2fb82759d1a2fecc0b8984a85456d1af'}, 'file_persistent_id': 'doi:10.25346/S6/ZJKUAC/APPCRU', 'dataset_name': 'Spring 2020 R Workshop', 'dataset_id': '20392', 'dataset_persistent_id': 'doi:10.25346/S6/ZJKUAC', 'dataset_citation': 'Data Science Center; Jamison, Jamie; Allen, Kristian; Phan, Leigh, 2020, "Spring 2020 R Workshop", https://doi.org/10.25346/S6/ZJKUAC, UCLA Dataverse, V9'}, {'name ...
# start: 30  total: 5067
# "Spring 2020 R Workshop",dataset,https://doi.org/10.25346/S6/ZJKUAC
# "Association of work-family experience with mid- and late-life memory decline in US women - Supplementary File",dataset,https://doi.org/10.25346/S6/ZR9FRC
# "TIMOTHY TANGHERLINI Dataverse",dataverse,https://dataverse.ucla.edu/dataverse/tango
# https://dataverse.ucla.edu//api/search?q=*&start=40
# {'status': 'OK', 'data': {'q': '*', 'total_count': 5067, 'start': 40, 'spelling_alternatives': {}, 'items': [{'name': 'Mayeda Research Group Dataverse', 'type': 'dataverse', 'url': 'https://dataverse.ucla.edu/dataverse/mayeda', 'identifier': 'mayeda', 'published_at': '2020-06-03T01:02:49Z'}, {'name': 'Replication Data for: An automated pipeline for the discovery of conspiracy and conspiracy theory narrative frameworks', 'type': 'dataset', 'url': 'https://doi.org/10.25346/S6/VTFXSX', 'global_id': 'doi:10.25346/S6/VTFXSX', 'description': 'Data for the paper, "An automated pipeline for the discovery of conspiracy and conspiracy theory narrative frameworks: Bridgegate, Pizzagate and storytelling on the web." The data consists of comments and posts to discussion forums related to the Pizzagate conspiracy theory, and to news articles related to the Bridgegate conspiracy. Data was cleaned for spam, photographs, extraneous records, and filtered to remove junk characters and other unrelated to topic. Metadata was retained for external verification purposes only. Please see accompanying article for preprocessing and data analysis methodologies. All of our data are from publicly available sources, and conform to the Terms of Services of their source sites.', 'published_at': '2020-06-03T19:42:46Z', 'publisher': 'TIMOTHY TANGHERLINI Dataverse', 'citationHtml': 'TANGHERLINI, TIMOTHY; Roychowdhury, Vwani, 2020, "Replication Data for: An automated pipeline for the discovery of conspiracy and conspiracy theory narrative frameworks", <a href="https://doi.org/10.25346/S6/VTFXSX" target="_blank">https://doi.org/10.25346/S6/VTFXSX</a>, UCLA Dataverse, V1', 'identifier_of_dataverse': 'tango', 'name_of_dataverse': 'TIMOTHY TANGHERLINI Dataverse', 'citation': 'TANGHERLINI, TIMOTHY; Roychowdhury, Vwani, 2020, "Replication Data for: An automated pipeline for the discovery of conspiracy and conspiracy theory narrative frameworks", https://doi.org/10.25346/S6/VTFXSX, UCLA Dataverse, V1', 'storageIdentifier': 's3://10.25346/S6/VTFXSX', 'keywords': ['Narrative, Machine Learning, Conspiracy Theory, Conspiracy, Politics, Rumor'], 'subjects': ['Computer and Information Science', 'Social Sciences', 'Other'], 'fileCount': 1, 'versionId': 1125, 'versionState': 'RELEASED', 'majorVersion': 1, 'minorVersion': 0, 'createdAt': '2020-05-14T21:46:51Z', 'updatedAt': '2020-06-03T19:42:46Z', 'contacts': [{'name': 'TANGHERLINI, TIMOTHY', 'affiliation': 'University of California, Los Angeles'}], 'authors': ['TANGHERLINI, TIMOTHY', 'Roychowdhury, Vwani']}, {'name': 'conspiracy.tgz', 'type': 'file', 'url': 'https://dataverse.ucla.edu/api/access/datafile/20467', 'file_id': '20467', 'description': 'Compressed directory containing Pizzagate and Bridgegate data, preprocessed for use in the pipeline described in the paper.', 'published_at': '2020-06-03T19:42:46Z', 'file_type': 'Gzip Archive', 'file_content_type': 'application/gzip', 'size_in_bytes': 1813474, 'md5': '756e1df05e3dfec747c8fb3b1718ae71', 'checksum': {'type': 'MD5', 'value': '756e1df05e3dfec747c8fb3b1718ae71'}, 'file_persistent_id': 'doi:10.25346/S6/VTFXSX/UWXCMQ', 'dataset_name': 'Replication Data for: An automated pipeline for the discovery of conspiracy and conspiracy theory narrative frameworks', 'dataset_id': '20466', 'dataset_persistent_id': 'doi:10.25346/S6/VTFXSX', 'dataset_citation': 'TANGHERLINI, TIMOTHY; Roychowdhury, Vwani, 2020, "Replication Data for: An automated pipeline for the discovery of conspiracy and conspiracy theory narrative frameworks", https://doi.org/10.25346/S6/VTFXSX, UCLA Dataverse, V1'}, {'name': 'Jamie Jamison', 'type': 'dataverse', 'url': 'https://dataverse.ucla.edu/dataverse/jmjtest', 'identifier': 'jmjtest', 'description': 'Dye plant class materials, 2018 (file testing)', 'published_at': '2018-10-03T18:05:18Z'}, {'name': 'UCLA Library Data Archive', 'type': 'dataverse', 'url': 'https://dataverse.ucla.edu/dataverse/ucla_dataarchive', 'identifier': 'ucla_dataarchive', 'description': 'Th ...
# start: 40  total: 5067
# "Mayeda Research Group Dataverse",dataverse,https://dataverse.ucla.edu/dataverse/mayeda
# "Replication Data for: An automated pipeline for the discovery of conspiracy and conspiracy theory narrative frameworks",dataset,https://doi.org/10.25346/S6/VTFXSX
# "Jamie Jamison",dataverse,https://dataverse.ucla.edu/dataverse/jmjtest
# "UCLA Library Data Archive",dataverse,https://dataverse.ucla.edu/dataverse/ucla_dataarchive
# "UCLA Library Materials",dataverse,https://dataverse.ucla.edu/dataverse/ucla-library-restricted
# "Dye Plant Class Material",dataverse,https://dataverse.ucla.edu/dataverse/jmj-dye-plant-class
# "Bill and Melinda Gates Foundation Data",dataverse,https://dataverse.ucla.edu/dataverse/gates-foundation
# "Replication data for: Stable rate of slip along the Karakax section of the Altyn Tagh Fault from observation of inter-glacial and post-glacial offset morphology and surface dating",dataverse,https://dataverse.ucla.edu/dataverse/atf_kx_landforms_crn_osl
# "NATHAN SMITH Dataverse",dataverse,https://dataverse.ucla.edu/dataverse/nathan-smith
# https://dataverse.ucla.edu//api/search?q=*&start=50
# {'status': 'OK', 'data': {'q': '*', 'total_count': 5067, 'start': 50, 'spelling_alternatives': {}, 'items': [{'name': 'Social Science Data Archive', 'type': 'dataverse', 'url': 'https://dataverse.ucla.edu/dataverse/ssda_ucla', 'identifier': 'ssda_ucla', 'description': 'The Social Science Data Archive has been operating at UCLA since 1961 when political science professor Dwaine Marvick established the Political Behavior Archive (PBA); through his efforts, UCLA was one of the 8 founding members of the Inter-university Consortium for Political and Social Research (ICPSR) in 1962. When the Survey Research Center (SRC) was formed in 1964, under the direction of Eve Fielder, the PBA was merged with a planned Archive Data Library the SRC was to house. In 1977, the research support framework of the Data Archive was designed by Professor Donald Treiman and implemented until it was re-organized into the UCLA Library in 2014. The mission of the Social Science Data Archive has been and continues to be to provide a foundation for social science research with faculty support throughout an entire research project involving original data collection or the reuse of publicly available studies. Data Archive staff and researchers work as partners throughout all stages of the research process, beginning when a hypothesis or area of study is being developed, during grant and funding activities, while data collection and/or analysis is ongoing, and finally in long term preservation of research results. Our role is to provide a collaborative environment where the focus is on understanding the nature and scope of research approach and management of research output throughout the entire life cycle of the project. Our Dataverse consists of unique surveys, enumerations, public opinion polls, and de-identified administrative records. Topics of studies include political attitudes and behavior; social and economic attitudes and behaviors; studies of health status and health outcomes; families, children, and women; international surveys of occupational and social mobility; the Los Angeles County Social Surveys; California Polls; and, census data for the United States and other countries. In addition, the SSDA provides access to data from the Inter-university Consortium for Political and Social Research and the Roper Center for Public Opinion Research. Materials from SSDA are used with software programs, such as SPSS, SAS, STATA, and R to carry out statistical analysis. Assistance in using statistical packages is provided by the IDRE Statistical consulting office. Instructional support, especially support that links research with instruction is also a mainstay of operations. The Data Archive is one of the key support components in those disciplines that provide instruction in research methods, survey design and methods, statistics, and data analysis. Throughout the campus, data provided by the Archive is used by faculty in courses to transmit pedagogy, illustrate theory and develop understanding of social, political, demographic, economic, geographic and historical trends and issues. throughout the entire life cycle of the project. Our Dataverse contains resources to help you find and analyze data, and tutorials to enrich your knowledge of data management practices and procedures. We provide advice in preparing data management plans and in applying for access to secure or restricted access datasets. If you are interested in sharing your data and need assistance in finding an appropriate archive, or would like help to document your data for the purpose of sharing, please contact us. For more information, see our Dataverse on Tutorials and Resources.', 'published_at': '2018-09-28T22:42:16Z'}, {'name': 'Gates Open Access Publishing Charges Project', 'type': 'dataset', 'url': 'https://doi.org/10.25346/S6/EEFYIP', 'global_id': 'doi:10.25346/S6/EEFYIP', 'description': 'This needs to be expanded later.', 'published_at': '2019-08-29T21:41:01Z', 'publisher': 'Bill and ...
# start: 50  total: 5067
# "Social Science Data Archive",dataverse,https://dataverse.ucla.edu/dataverse/ssda_ucla
# "Gates Open Access Publishing Charges Project",dataset,https://doi.org/10.25346/S6/EEFYIP
# "UCLA Open Archive",dataverse,https://dataverse.ucla.edu/dataverse/ucla_openarchive
# "test after aws move",dataverse,https://dataverse.ucla.edu/dataverse/post-move-test2
# "direct upload test DEM",dataset,https://doi.org/10.25346/S6/UJOJHE
# https://dataverse.ucla.edu//api/search?q=*&start=60
# {'status': 'OK', 'data': {'q': '*', 'total_count': 5067, 'start': 60, 'spelling_alternatives': {}, 'items': [{'name': 'Rapid Analytical Instrumentation for Electrochemical Impedance Spectroscopy Measurements', 'type': 'dataset', 'url': 'https://doi.org/10.25346/S6/WDRBKE', 'global_id': 'doi:10.25346/S6/WDRBKE', 'description': 'This work reports a low-cost custom electrochemical instrument capable of performing rapid and accurate electrochemical impedance spectroscopy (EIS) for supercapacitors over a broad frequency band (10 mHz to 2 kHz). Conventionally, EIS is measured via sinusoidal perturbations; however, such an approach suffers from lengthy measurement time. Chirp signals have been shown previously to reduce EIS measurement time for supercapacitors for relative narrow frequency bands (1 Hz to 2 kHz). However, to characterize supercapacitors comprehensively, much broader frequency bands are required. Here, we present a custom instrument with an adaptive measurement algorithm for performing EIS measurements in a wide frequency range of 10 mHz to 2 kHz with low measurement uncertainties. The results obtained using this new technique has been validated here with a commercial instrument on several types of supercapacitors. Furthermore, measurement time on average decreases from 1500 s to less than 400 s. The overall cost of the custom instrument is 90% lower as compared to the commercial instrument. The custom instrument’s accuracy, time efficiency and low cost are expected to benefit electrochemical researchers.', 'published_at': '2020-07-15T20:41:27Z', 'publisher': 'UCLA Mechanical & Aerospace Engineering', 'citationHtml': 'Hu, Yuan; Brahim, Sean; Maat, Stefan; Davies, Patricia; Kundu, Arpan; Fisher, Timothy S., 2020, "Rapid Analytical Instrumentation for Electrochemical Impedance Spectroscopy Measurements", <a href="https://doi.org/10.25346/S6/WDRBKE" target="_blank">https://doi.org/10.25346/S6/WDRBKE</a>, UCLA Dataverse, V1', 'identifier_of_dataverse': 'mae', 'name_of_dataverse': 'UCLA Mechanical & Aerospace Engineering', 'citation': 'Hu, Yuan; Brahim, Sean; Maat, Stefan; Davies, Patricia; Kundu, Arpan; Fisher, Timothy S., 2020, "Rapid Analytical Instrumentation for Electrochemical Impedance Spectroscopy Measurements", https://doi.org/10.25346/S6/WDRBKE, UCLA Dataverse, V1', 'storageIdentifier': 's3://10.25346/S6/WDRBKE', 'subjects': ['Engineering'], 'fileCount': 3, 'versionId': 1151, 'versionState': 'RELEASED', 'majorVersion': 1, 'minorVersion': 0, 'createdAt': '2020-07-14T23:21:17Z', 'updatedAt': '2020-07-15T20:41:27Z', 'contacts': [{'name': '', 'affiliation': ''}], 'publications': [{}], 'authors': ['Hu, Yuan', 'Brahim, Sean', 'Maat, Stefan', 'Davies, Patricia', 'Kundu, Arpan', 'Fisher, Timothy S.']}, {'name': 'demo_variational_chirp.csv', 'type': 'file', 'url': 'https://dataverse.ucla.edu/api/access/datafile/20841', 'file_id': '20841', 'published_at': '2020-07-15T20:41:27Z', 'file_type': 'Comma Separated Values', 'file_content_type': 'text/csv', 'size_in_bytes': 7473, 'md5': '2625dd14f8b7a03c626ee0779bec0a21', 'checksum': {'type': 'MD5', 'value': '2625dd14f8b7a03c626ee0779bec0a21'}, 'file_persistent_id': 'doi:10.25346/S6/WDRBKE/IYTSZN', 'dataset_name': 'Rapid Analytical Instrumentation for Electrochemical Impedance Spectroscopy Measurements', 'dataset_id': '20839', 'dataset_persistent_id': 'doi:10.25346/S6/WDRBKE', 'dataset_citation': 'Hu, Yuan; Brahim, Sean; Maat, Stefan; Davies, Patricia; Kundu, Arpan; Fisher, Timothy S., 2020, "Rapid Analytical Instrumentation for Electrochemical Impedance Spectroscopy Measurements", https://doi.org/10.25346/S6/WDRBKE, UCLA Dataverse, V1'}, {'name': 'Hu_2020_J._Electrochem._Soc._167_027545.pdf', 'type': 'file', 'url': 'https://dataverse.ucla.edu/api/access/datafile/20842', 'file_id': '20842', 'published_at': '2020-07-15T20:41:27Z', 'file_type': 'Adobe PDF', 'file_content_type': 'application/pdf', 'size_in_bytes': 1754383, 'md5': 'cd0f63eb1677b25086919cfd77aba7b4', 'checksum': {'type' ...
# start: 60  total: 5067
# "Rapid Analytical Instrumentation for Electrochemical Impedance Spectroscopy Measurements",dataset,https://doi.org/10.25346/S6/WDRBKE
# "UCLA Mechanical & Aerospace Engineering",dataverse,https://dataverse.ucla.edu/dataverse/mae
# "UCLA Data Science Center",dataverse,https://dataverse.ucla.edu/dataverse/dsc
# "Dye Plant Class Materials",dataset,https://doi.org/10.25346/S6/EZYHS4
# https://dataverse.ucla.edu//api/search?q=*&start=70
# {'status': 'OK', 'data': {'q': '*', 'total_count': 5067, 'start': 70, 'spelling_alternatives': {}, 'items': [{'name': 'dyeDataSheetNatDye.doc', 'type': 'file', 'url': 'https://dataverse.ucla.edu/api/access/datafile/4963', 'file_id': '4963', 'published_at': '2019-09-10T18:13:05Z', 'file_type': 'MS Word', 'file_content_type': 'application/msword', 'size_in_bytes': 28160, 'md5': '7c564894a3d7f3e716668a6220d8309e', 'checksum': {'type': 'MD5', 'value': '7c564894a3d7f3e716668a6220d8309e'}, 'file_persistent_id': 'doi:10.25346/S6/EZYHS4/EKTIEH', 'dataset_name': 'Dye Plant Class Materials', 'dataset_id': '4949', 'dataset_persistent_id': 'doi:10.25346/S6/EZYHS4', 'dataset_citation': 'JAMISON, JINA, 2019, "Dye Plant Class Materials", https://doi.org/10.25346/S6/EZYHS4, UCLA Dataverse, V5'}, {'name': 'dyersBibliography.doc', 'type': 'file', 'url': 'https://dataverse.ucla.edu/api/access/datafile/4967', 'file_id': '4967', 'published_at': '2019-09-10T18:13:05Z', 'file_type': 'MS Word', 'file_content_type': 'application/msword', 'size_in_bytes': 15360, 'md5': '712adef8feaca7dfd65385ef419d5c10', 'checksum': {'type': 'MD5', 'value': '712adef8feaca7dfd65385ef419d5c10'}, 'file_persistent_id': 'doi:10.25346/S6/EZYHS4/2LAQXI', 'dataset_name': 'Dye Plant Class Materials', 'dataset_id': '4949', 'dataset_persistent_id': 'doi:10.25346/S6/EZYHS4', 'dataset_citation': 'JAMISON, JINA, 2019, "Dye Plant Class Materials", https://doi.org/10.25346/S6/EZYHS4, UCLA Dataverse, V5'}, {'name': 'madderDirections.doc', 'type': 'file', 'url': 'https://dataverse.ucla.edu/api/access/datafile/4964', 'file_id': '4964', 'published_at': '2019-09-10T18:13:05Z', 'file_type': 'MS Word', 'file_content_type': 'application/msword', 'size_in_bytes': 17920, 'md5': '22cad8be7e601ed1bf365e3a6e04242d', 'checksum': {'type': 'MD5', 'value': '22cad8be7e601ed1bf365e3a6e04242d'}, 'file_persistent_id': 'doi:10.25346/S6/EZYHS4/FHXGGJ', 'dataset_name': 'Dye Plant Class Materials', 'dataset_id': '4949', 'dataset_persistent_id': 'doi:10.25346/S6/EZYHS4', 'dataset_citation': 'JAMISON, JINA, 2019, "Dye Plant Class Materials", https://doi.org/10.25346/S6/EZYHS4, UCLA Dataverse, V5'}, {'name': 'madderDirections.rtf', 'type': 'file', 'url': 'https://dataverse.ucla.edu/api/access/datafile/4960', 'file_id': '4960', 'description': 'Madder directions', 'published_at': '2019-09-10T18:09:43Z', 'file_type': 'Rich Text Format', 'file_content_type': 'application/rtf', 'size_in_bytes': 13372, 'md5': 'cf8c30eecbebecb173b891abed69d847', 'checksum': {'type': 'MD5', 'value': 'cf8c30eecbebecb173b891abed69d847'}, 'file_persistent_id': 'doi:10.25346/S6/EZYHS4/2FI2DX', 'dataset_name': 'Dye Plant Class Materials', 'dataset_id': '4949', 'dataset_persistent_id': 'doi:10.25346/S6/EZYHS4', 'dataset_citation': 'JAMISON, JINA, 2019, "Dye Plant Class Materials", https://doi.org/10.25346/S6/EZYHS4, UCLA Dataverse, V5'}, {'name': 'woadDirections.doc', 'type': 'file', 'url': 'https://dataverse.ucla.edu/api/access/datafile/4965', 'file_id': '4965', 'published_at': '2019-09-10T18:13:05Z', 'file_type': 'MS Word', 'file_content_type': 'application/msword', 'size_in_bytes': 17920, 'md5': 'd3d87d1a9c03bca1be4daf8b7e5f9a9b', 'checksum': {'type': 'MD5', 'value': 'd3d87d1a9c03bca1be4daf8b7e5f9a9b'}, 'file_persistent_id': 'doi:10.25346/S6/EZYHS4/L3TGXX', 'dataset_name': 'Dye Plant Class Materials', 'dataset_id': '4949', 'dataset_persistent_id': 'doi:10.25346/S6/EZYHS4', 'dataset_citation': 'JAMISON, JINA, 2019, "Dye Plant Class Materials", https://doi.org/10.25346/S6/EZYHS4, UCLA Dataverse, V5'}, {'name': 'woadDirections.rtf', 'type': 'file', 'url': 'https://dataverse.ucla.edu/api/access/datafile/4959', 'file_id': '4959', 'description': 'Woad directions', 'published_at': '2019-09-10T18:09:43Z', 'file_type': 'Rich Text Format', 'file_content_type': 'application/rtf', 'size_in_bytes': 12651, 'md5': '97b4cf7c7b4febb9dadbd617ac013efe', 'checksum': {'type': 'MD5', 'value': '97b4cf7c7b4febb9dadbd617ac013efe'}, 'file_persistent_id': 'doi:10.25 ...
# start: 70  total: 5067
# "Los Angeles Region Imagery Acquisition Consortium (LARIAC)",dataverse,https://dataverse.ucla.edu/dataverse/lariac
# "lariac4",dataset,https://doi.org/10.25346/S6/T4LHZF
# https://dataverse.ucla.edu//api/search?q=*&start=80
# {'status': 'OK', 'data': {'q': '*', 'total_count': 5067, 'start': 80, 'spelling_alternatives': {}, 'items': [{'name': 'LARIAC5', 'type': 'dataverse', 'url': 'https://dataverse.ucla.edu/dataverse/lariac5', 'identifier': 'lariac5', 'description': 'LARIAC5 files', 'published_at': '2020-09-03T21:13:16Z'}, {'name': 'LARIAC4', 'type': 'dataverse', 'url': 'https://dataverse.ucla.edu/dataverse/lariac4', 'identifier': 'lariac4', 'description': 'LARIAC4 files', 'published_at': '2020-09-03T21:19:32Z'}, {'name': 'Reports: Accuracy Assessment', 'type': 'dataset', 'url': 'https://doi.org/10.25346/S6/HOFGDJ', 'global_id': 'doi:10.25346/S6/HOFGDJ', 'description': 'LARIAC5 Reports', 'published_at': '2020-09-03T19:37:16Z', 'publisher': 'LARIAC5', 'citationHtml': 'JAMISON, JINA, 2020, "Reports: Accuracy Assessment", <a href="https://doi.org/10.25346/S6/HOFGDJ" target="_blank">https://doi.org/10.25346/S6/HOFGDJ</a>, UCLA Dataverse, V6', 'identifier_of_dataverse': 'lariac5', 'name_of_dataverse': 'LARIAC5', 'citation': 'JAMISON, JINA, 2020, "Reports: Accuracy Assessment", https://doi.org/10.25346/S6/HOFGDJ, UCLA Dataverse, V6', 'storageIdentifier': 's3-dataverse-lariac://10.25346/S6/HOFGDJ', 'subjects': ['Social Sciences'], 'fileCount': 2, 'versionId': 1172, 'versionState': 'RELEASED', 'majorVersion': 6, 'minorVersion': 2, 'createdAt': '2020-06-07T16:34:08Z', 'updatedAt': '2020-09-03T21:35:35Z', 'contacts': [{'name': 'JAMISON, JINA', 'affiliation': 'University of California, Los Angeles'}], 'publications': [{}], 'geographicCoverage': [{'country': ''}], 'authors': ['JAMISON, JINA']}, {'name': 'Reports.zip', 'type': 'file', 'url': 'https://dataverse.ucla.edu/api/access/datafile/21065', 'file_id': '21065', 'description': 'LARIAC5 Reports: Accuracy Assessment', 'published_at': '2020-09-03T19:23:04Z', 'file_type': 'ZIP Archive', 'file_content_type': 'application/zip', 'size_in_bytes': 341, 'md5': 'e8d7f7e2fa14697e81b9c31cbc4af719', 'checksum': {'type': 'MD5', 'value': 'e8d7f7e2fa14697e81b9c31cbc4af719'}, 'file_persistent_id': 'doi:10.25346/S6/HOFGDJ/DTCNBM', 'dataset_name': 'Reports: Accuracy Assessment', 'dataset_id': '20628', 'dataset_persistent_id': 'doi:10.25346/S6/HOFGDJ', 'dataset_citation': 'JAMISON, JINA, 2020, "Reports: Accuracy Assessment", https://doi.org/10.25346/S6/HOFGDJ, UCLA Dataverse, V6'}, {'name': 'Shapefiles.zip', 'type': 'file', 'url': 'https://dataverse.ucla.edu/api/access/datafile/21064', 'file_id': '21064', 'description': 'Shape files: Ortho Imagery Grid', 'published_at': '2020-09-03T19:21:01Z', 'file_type': 'ZIP Archive', 'file_content_type': 'application/zip', 'size_in_bytes': 388969, 'md5': 'd7f012db9a02c1f365cb26c735932d29', 'checksum': {'type': 'MD5', 'value': 'd7f012db9a02c1f365cb26c735932d29'}, 'file_persistent_id': 'doi:10.25346/S6/HOFGDJ/60ACHA', 'dataset_name': 'Reports: Accuracy Assessment', 'dataset_id': '20628', 'dataset_persistent_id': 'doi:10.25346/S6/HOFGDJ', 'dataset_citation': 'JAMISON, JINA, 2020, "Reports: Accuracy Assessment", https://doi.org/10.25346/S6/HOFGDJ, UCLA Dataverse, V6'}, {'name': 'Association of work-family experience with mid- and late-life memory decline in US women - Supplementary File', 'type': 'dataset', 'url': 'https://doi.org/10.25346/S6/UKL1KC', 'global_id': 'doi:10.25346/S6/UKL1KC', 'description': 'Supplemental file for manuscript "Association of work-family experience with mid- and late-life memory decline in US women"', 'published_at': '2020-07-14T17:57:52Z', 'publisher': 'UCLA Dataverse', 'citationHtml': 'MAYEDA, ELIZABETH ROSE; MOBLEY, TAYLOR M.; WEISS, ROBERT E.; MURCHLAND, AUDREY R.; BERKMAN, LISA F.; SABBATH, ERIKA L., 2020, "Association of work-family experience with mid- and late-life memory decline in US women - Supplementary File", <a href="https://doi.org/10.25346/S6/UKL1KC" target="_blank">https://doi.org/10.25346/S6/UKL1KC</a>, UCLA Dataverse, V1', 'identifier_of_dataverse': 'ucla', 'name_of_dataverse': 'UCLA Dataverse', 'citation': 'MAYEDA, ELIZABETH ROSE; MOBLEY, TAYLOR M ...
# start: 80  total: 5067
# "LARIAC5",dataverse,https://dataverse.ucla.edu/dataverse/lariac5
# "LARIAC4",dataverse,https://dataverse.ucla.edu/dataverse/lariac4
# "Reports: Accuracy Assessment",dataset,https://doi.org/10.25346/S6/HOFGDJ
# "Association of work-family experience with mid- and late-life memory decline in US women - Supplementary File",dataset,https://doi.org/10.25346/S6/UKL1KC
# "Ortho Imagery Grid Shapefile",dataset,https://doi.org/10.25346/S6/XZ36OQ
# "Brain Volume Fractions Across Mammals with Relation to Behavior in Carnivores, Primates, Ungulates, and Rodents Data",dataset,https://doi.org/10.25346/S6/GKSJCU
# https://dataverse.ucla.edu//api/search?q=*&start=90
# {'status': 'OK', 'data': {'q': '*', 'total_count': 5067, 'start': 90, 'spelling_alternatives': {}, 'items': [{'name': 'BBE-2020-Grisham et al.tab', 'type': 'file', 'url': 'https://dataverse.ucla.edu/api/access/datafile/20824', 'file_id': '20824', 'published_at': '2020-06-16T23:13:58Z', 'file_type': 'Tab-Delimited', 'file_content_type': 'text/tab-separated-values', 'size_in_bytes': 12245, 'md5': 'fab26d0341d83f4f19c0544f90fb1921', 'checksum': {'type': 'MD5', 'value': 'fab26d0341d83f4f19c0544f90fb1921'}, 'unf': 'UNF:6:MKxiVT7ZpgfL5UDZCvh0Xw==', 'file_persistent_id': 'doi:10.25346/S6/GKSJCU/QQD9NK', 'dataset_name': 'Brain Volume Fractions Across Mammals with Relation to Behavior in Carnivores, Primates, Ungulates, and Rodents Data', 'dataset_id': '20818', 'dataset_persistent_id': 'doi:10.25346/S6/GKSJCU', 'dataset_citation': 'GRISHAM, WILLIAM, 2020, "Brain Volume Fractions Across Mammals with Relation to Behavior in Carnivores, Primates, Ungulates, and Rodents Data", https://doi.org/10.25346/S6/GKSJCU, UCLA Dataverse, V1, UNF:6:MKxiVT7ZpgfL5UDZCvh0Xw== [fileUNF]'}, {'name': 'READ_ME__BBE_2020_Grisham_et_al.txt', 'type': 'file', 'url': 'https://dataverse.ucla.edu/api/access/datafile/20825', 'file_id': '20825', 'description': 'Read Me for accompanying data set', 'published_at': '2020-06-16T23:13:58Z', 'file_type': 'Plain Text', 'file_content_type': 'text/plain', 'size_in_bytes': 3609, 'md5': 'ba9ef2b9ee01af3118902d665759995d', 'checksum': {'type': 'MD5', 'value': 'ba9ef2b9ee01af3118902d665759995d'}, 'file_persistent_id': 'doi:10.25346/S6/GKSJCU/UOQD6N', 'dataset_name': 'Brain Volume Fractions Across Mammals with Relation to Behavior in Carnivores, Primates, Ungulates, and Rodents Data', 'dataset_id': '20818', 'dataset_persistent_id': 'doi:10.25346/S6/GKSJCU', 'dataset_citation': 'GRISHAM, WILLIAM, 2020, "Brain Volume Fractions Across Mammals with Relation to Behavior in Carnivores, Primates, Ungulates, and Rodents Data", https://doi.org/10.25346/S6/GKSJCU, UCLA Dataverse, V1, UNF:6:MKxiVT7ZpgfL5UDZCvh0Xw== [fileUNF]'}, {'name': 'Paloma and Associates Open Access Cost Transparency Project Replication Data', 'type': 'dataset', 'url': 'https://doi.org/10.25346/S6/VODY5G', 'global_id': 'doi:10.25346/S6/VODY5G', 'description': 'Replication data for Paloma and Associates Open Access Cost Transparency Project Replication Data', 'published_at': '2019-11-15T18:02:33Z', 'publisher': 'UCLA Dataverse', 'citationHtml': 'Dove, John G., 2019, "Paloma and Associates Open Access Cost Transparency Project Replication Data", <a href="https://doi.org/10.25346/S6/VODY5G" target="_blank">https://doi.org/10.25346/S6/VODY5G</a>, UCLA Dataverse, V2, UNF:6:XpFCGvW+rOgtNoxHtJ5tZQ== [fileUNF]', 'identifier_of_dataverse': 'ucla', 'name_of_dataverse': 'UCLA Dataverse', 'citation': 'Dove, John G., 2019, "Paloma and Associates Open Access Cost Transparency Project Replication Data", https://doi.org/10.25346/S6/VODY5G, UCLA Dataverse, V2, UNF:6:XpFCGvW+rOgtNoxHtJ5tZQ== [fileUNF]', 'storageIdentifier': 's3://10.25346/S6/VODY5G', 'subjects': ['Social Sciences'], 'fileCount': 3, 'versionId': 1061, 'versionState': 'RELEASED', 'majorVersion': 2, 'minorVersion': 0, 'createdAt': '2019-10-31T23:35:23Z', 'updatedAt': '2019-11-15T18:02:33Z', 'contacts': [{'name': 'JAMISON, JINA', 'affiliation': 'University of California, Los Angeles'}], 'authors': ['Dove, John G.']}, {'name': 'Paloma APC Transparency Project Gates Invoices 1 July 2016 to 31 March 2019  Research Dataset Codebook.docx', 'type': 'file', 'url': 'https://dataverse.ucla.edu/api/access/datafile/19501', 'file_id': '19501', 'description': 'Codebook in MS Word format', 'published_at': '2019-10-31T23:44:14Z', 'file_type': 'MS Word', 'file_content_type': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'size_in_bytes': 42943, 'md5': '269c7672d623e71d479cca9f3990f998', 'checksum': {'type': 'MD5', 'value': '269c7672d623e71d479cca9f3990f998'}, 'file_persistent_id': 'doi:10.25346/S6/VODY5G/ZYXW4Z' ...
# start: 90  total: 5067
# "Paloma and Associates Open Access Cost Transparency Project Replication Data",dataset,https://doi.org/10.25346/S6/VODY5G
# "Replication Data for: "A Comparison of Radial Diffusion Coefficients in 1-D and 3-D Long-Term Radiation Belt Simulations"",dataset,https://doi.org/10.25346/S6/U9WFPD
# https://dataverse.ucla.edu//api/search?q=*&start=100
# ...
# start: 2900  total: 5067
# https://dataverse.ucla.edu//api/search?q=*&start=2910
# {'status': 'OK', 'data': {'q': '*', 'total_count': 5067, 'start': 2910, 'spelling_alternatives': {}, 'items': [{'name': 'DTA572.file0065.CIRES.JUN96.FREQ', 'type': 'file', 'url': 'https://dataverse.ucla.edu/api/access/datafile/7758', 'file_id': '7758', 'description': 'June - Political and economic culture. Frequency report in text format.', 'published_at': '2019-09-10T19:42:25Z', 'file_type': 'Plain Text', 'file_content_type': 'text/plain; charset=US-ASCII', 'size_in_bytes': -1, 'md5': 'unknown', 'checksum': {'type': 'MD5', 'value': 'unknown'}, 'dataset_name': 'Centro de Investigaciones sobre la Realidad Social (CIRES) [Spain], 1996 (M608V1)', 'dataset_id': '7749', 'dataset_persistent_id': 'hdl:1902.1/M608V1', 'dataset_citation': 'Centro de Estudios sobre la Realidad Social, 2016, "Centro de Investigaciones sobre la Realidad Social (CIRES) [Spain], 1996 (M608V1)", https://hdl.handle.net/1902.1/M608V1, Harvard Dataverse'}, {'name': 'DTA572.file0066.CIRES.JUN96.SPSS', 'type': 'file', 'url': 'https://dataverse.ucla.edu/api/access/datafile/7759', 'file_id': '7759', 'description': 'June - Political and economic culture. SPSS data definition file.', 'published_at': '2019-09-10T19:42:25Z', 'file_type': 'Plain Text', 'file_content_type': 'text/plain; charset=US-ASCII', 'size_in_bytes': -1, 'md5': 'unknown', 'checksum': {'type': 'MD5', 'value': 'unknown'}, 'dataset_name': 'Centro de Investigaciones sobre la Realidad Social (CIRES) [Spain], 1996 (M608V1)', 'dataset_id': '7749', 'dataset_persistent_id': 'hdl:1902.1/M608V1', 'dataset_citation': 'Centro de Estudios sobre la Realidad Social, 2016, "Centro de Investigaciones sobre la Realidad Social (CIRES) [Spain], 1996 (M608V1)", https://hdl.handle.net/1902.1/M608V1, Harvard Dataverse'}, {'name': 'Los Angeles Metropolitan Area Surveys [LAMAS] 2, 1970', 'type': 'dataset', 'url': 'https://hdl.handle.net/1902.1/M269V1P2', 'global_id': 'hdl:1902.1/M269V1P2', 'description': "The Los Angeles Metropolitan Areas Studies (LAMAS) were conducted ten times between 1970 and 1976. The goal of the LAMAS studies is the development of a set of standard community profile measures appropriate for use in the planning and evaluation of public policy. In addition, individual study participants have the option of submitting questions to be asked in addition to the core items. Questions in this survey cover respondents' attitudes toward the following topics: life satisfaction, air pollution, health care services in the community, local government politics, voting behavior, police relations, recreation and leisure time. Study participants' question topics include: clean air, mobility, political attitudes, education, integration/segregation, and health care knowledge, diets, causes of diseases, travel time to work. This study is provided 'as is' and questions can be directed to the Data Archive staff.", 'published_at': '2019-04-23T07:06:09Z', 'publisher': 'Social Science Data Archive', 'citationHtml': 'University of California, Los Angeles. Institute for Social Science Research., 2011, "Los Angeles Metropolitan Area Surveys [LAMAS] 2, 1970", <a href="https://hdl.handle.net/1902.1/M269V1P2" target="_blank">https://hdl.handle.net/1902.1/M269V1P2</a>, Harvard Dataverse', 'identifier_of_dataverse': 'ssda_ucla', 'name_of_dataverse': 'Social Science Data Archive', 'citation': 'University of California, Los Angeles. Institute for Social Science Research., 2011, "Los Angeles Metropolitan Area Surveys [LAMAS] 2, 1970", https://hdl.handle.net/1902.1/M269V1P2, Harvard Dataverse', 'storageIdentifier': 's3://1902.1/M269V1P2', 'subjects': [], 'fileCount': 2, 'versionId': 986, 'versionState': 'RELEASED', 'createdAt': '2019-09-10T19:42:24Z', 'updatedAt': '2019-09-10T19:42:24Z', 'contacts': [{'name': '', 'affiliation': ''}], 'producers': ['University of California, Los Angeles. Survey Research Center.'], 'geographicCoverage': [{'country': 'United States'}, {'other': 'Los Angeles county,'}], 'authors': ['University of California, Lo ...
# start: 2910  total: 5067
# "Los Angeles Metropolitan Area Surveys [LAMAS] 2, 1970",dataset,https://hdl.handle.net/1902.1/M269V1P2
# "U.S. Survey of Unmarried Women Under 18 in Family Planning Clinics, 1979-1980",dataset,https://hdl.handle.net/1902.1/M059V1
# https://dataverse.ucla.edu//api/search?q=*&start=2920
# {'status': 'OK', 'data': {'q': '*', 'total_count': 5067, 'start': 2920, 'spelling_alternatives': {}, 'items': [{'name': 'DTA900.file5791.JF28.DATA.por', 'type': 'file', 'url': 'https://dataverse.ucla.edu/api/access/datafile/7770', 'file_id': '7770', 'description': 'Data in SPSS portable format', 'published_at': '2019-09-10T19:42:26Z', 'file_type': 'SPSS Portable', 'file_content_type': 'application/x-spss-por', 'size_in_bytes': -1, 'md5': 'unknown', 'checksum': {'type': 'MD5', 'value': 'unknown'}, 'dataset_name': 'U.S. Survey of Unmarried Women Under 18 in Family Planning Clinics, 1979-1980', 'dataset_id': '7766', 'dataset_persistent_id': 'hdl:1902.1/M059V1', 'dataset_citation': 'Aida Torres, 2013, "U.S. Survey of Unmarried Women Under 18 in Family Planning Clinics, 1979-1980", https://hdl.handle.net/1902.1/M059V1, Harvard Dataverse'}, {'name': 'California Poll: 2000-04 -- August 18-22, 2000', 'type': 'dataset', 'url': 'https://hdl.handle.net/1902.1/CP2000P2000-04', 'global_id': 'hdl:1902.1/CP2000P2000-04', 'description': 'The Field Poll, established in 1945 as The California Poll by Mervin Field, has operated continuously as an independent, non-partisan, media-sponsored public opinion news service. Each year the Field Polls cover a wide range of political and social topics examining California public opinion. Continuing measures are made of voter support for leading political figures vying for major state and federal offices, job ratings of important political figures and reactions to significant political events. Voter awareness, understanding and predispositions of major campaign issues and salient statewide ballot propositions are also tracked over time. For poll 2000-04 N=505.', 'published_at': '2019-04-23T07:06:09Z', 'publisher': 'Social Science Data Archive', 'citationHtml': 'Field Research Corporation., 2011, "California Poll: 2000-04 -- August 18-22, 2000", <a href="https://hdl.handle.net/1902.1/CP2000P2000-04" target="_blank">https://hdl.handle.net/1902.1/CP2000P2000-04</a>, Harvard Dataverse', 'identifier_of_dataverse': 'ssda_ucla', 'name_of_dataverse': 'Social Science Data Archive', 'citation': 'Field Research Corporation., 2011, "California Poll: 2000-04 -- August 18-22, 2000", https://hdl.handle.net/1902.1/CP2000P2000-04, Harvard Dataverse', 'storageIdentifier': 's3://1902.1/CP2000P2000-04', 'subjects': [], 'fileCount': 5, 'versionId': 989, 'versionState': 'RELEASED', 'createdAt': '2019-09-10T19:42:26Z', 'updatedAt': '2019-09-10T19:42:26Z', 'contacts': [{'name': '', 'affiliation': ''}], 'producers': ['Field Research Corporation.'], 'geographicCoverage': [{'country': 'United States'}, {'other': 'California,'}], 'authors': ['Field Research Corporation.']}, {'name': 'DTA900.file1954.CP0104.DATA', 'type': 'file', 'url': 'https://dataverse.ucla.edu/api/access/datafile/7775', 'file_id': '7775', 'description': 'Data in ASCII format', 'published_at': '2019-09-10T19:42:26Z', 'file_type': 'Plain Text', 'file_content_type': 'text/plain; charset=US-ASCII', 'size_in_bytes': -1, 'md5': 'unknown', 'checksum': {'type': 'MD5', 'value': 'unknown'}, 'dataset_name': 'California Poll: 2000-04 -- August 18-22, 2000', 'dataset_id': '7772', 'dataset_persistent_id': 'hdl:1902.1/CP2000P2000-04', 'dataset_citation': 'Field Research Corporation., 2011, "California Poll: 2000-04 -- August 18-22, 2000", https://hdl.handle.net/1902.1/CP2000P2000-04, Harvard Dataverse'}, {'name': 'DTA900.file1955.CP0104.tab', 'type': 'file', 'url': 'https://dataverse.ucla.edu/api/access/datafile/7773', 'file_id': '7773', 'description': 'Data in SPSS portable format', 'published_at': '2019-09-10T19:42:26Z', 'file_type': 'Tab-Delimited', 'file_content_type': 'text/tab-separated-values', 'size_in_bytes': -1, 'md5': 'unknown', 'checksum': {'type': 'MD5', 'value': 'unknown'}, 'dataset_name': 'California Poll: 2000-04 -- August 18-22, 2000', 'dataset_id': '7772', 'dataset_persistent_id': 'hdl:1902.1/CP2000P2000-04', 'dataset_citation': 'Field Research Corporation., 20 ...
# start: 2920  total: 5067
# "California Poll: 2000-04 -- August 18-22, 2000",dataset,https://hdl.handle.net/1902.1/CP2000P2000-04
# "California Poll: 6201 -- February 1-7, 1962",dataset,https://hdl.handle.net/1902.1/CP5680P6201
# https://dataverse.ucla.edu//api/search?q=*&start=2930
# {'status': 'OK', 'data': {'q': '*', 'total_count': 5067, 'start': 2930, 'spelling_alternatives': {}, 'items': [{'name': 'Population Census [South Africa], 1985 (M921V1)', 'type': 'dataset', 'url': 'https://hdl.handle.net/1902.1/M921V1', 'global_id': 'hdl:1902.1/M921V1', 'description': 'ABSTRACT: The 1985 Population Census was enumerated on a de facto basis, that is, according to the place where persons were located during the census. All persons who were present on Republic of South African territory during census night were enumerated and included in the data. Visitors from abroad who were present in the RSA on holiday or business on the night of the census, as well as foreigners (and their families) who were studying or economically active, were enumerated but not included in the figures. Likewise, members of the Diplomatic and Consular Corps of foreign countries were not included. However, the South African personnel linked to the foreign missions including domestic workers were enumerated. Crews and passengers of ships were also not enumerated, unless they were normally resident in the Republic of South Africa. Residents of the RSA who were absent from the night were as far as possible enumerated on their return and included in the region where they normally resided. Personnel of the South African Government stationed abroad and their families were, however enumerated. Such persons were included in the Transvaal (Pretoria).', 'published_at': '2019-04-23T07:06:09Z', 'publisher': 'Social Science Data Archive', 'citationHtml': 'Statistics South Africa, 2016, "Population Census [South Africa], 1985 (M921V1)", <a href="https://hdl.handle.net/1902.1/M921V1" target="_blank">https://hdl.handle.net/1902.1/M921V1</a>, Harvard Dataverse', 'identifier_of_dataverse': 'ssda_ucla', 'name_of_dataverse': 'Social Science Data Archive', 'citation': 'Statistics South Africa, 2016, "Population Census [South Africa], 1985 (M921V1)", https://hdl.handle.net/1902.1/M921V1, Harvard Dataverse', 'storageIdentifier': 's3://1902.1/M921V1', 'keywords': ['Social Sciences'], 'subjects': [], 'fileCount': 10, 'versionId': 992, 'versionState': 'RELEASED', 'createdAt': '2019-09-10T19:42:28Z', 'updatedAt': '2019-09-10T19:42:28Z', 'contacts': [{'name': '', 'affiliation': ''}], 'producers': ['Statistics South Africa'], 'geographicCoverage': [{'country': 'South Africa'}], 'authors': ['Statistics South Africa']}, {'name': 'DTA900.file2922.S0070.PDF', 'type': 'file', 'url': 'https://dataverse.ucla.edu/api/access/datafile/7792', 'file_id': '7792', 'description': 'Codebook in PDF format.', 'published_at': '2019-09-10T19:42:28Z', 'file_type': 'Adobe PDF', 'file_content_type': 'application/pdf', 'size_in_bytes': -1, 'md5': 'unknown', 'checksum': {'type': 'MD5', 'value': 'unknown'}, 'dataset_name': 'Population Census [South Africa], 1985 (M921V1)', 'dataset_id': '7784', 'dataset_persistent_id': 'hdl:1902.1/M921V1', 'dataset_citation': 'Statistics South Africa, 2016, "Population Census [South Africa], 1985 (M921V1)", https://hdl.handle.net/1902.1/M921V1, Harvard Dataverse'}, {'name': 'DTA900.file2923.AREA85A.POR', 'type': 'file', 'url': 'https://dataverse.ucla.edu/api/access/datafile/7791', 'file_id': '7791', 'description': 'AREA85A data in SPSS portable format.', 'published_at': '2019-09-10T19:42:28Z', 'file_type': 'SPSS Portable', 'file_content_type': 'application/x-spss-por', 'size_in_bytes': -1, 'md5': 'unknown', 'checksum': {'type': 'MD5', 'value': 'unknown'}, 'dataset_name': 'Population Census [South Africa], 1985 (M921V1)', 'dataset_id': '7784', 'dataset_persistent_id': 'hdl:1902.1/M921V1', 'dataset_citation': 'Statistics South Africa, 2016, "Population Census [South Africa], 1985 (M921V1)", https://hdl.handle.net/1902.1/M921V1, Harvard Dataverse'}, {'name': 'DTA900.file2924.AREA85B.POR', 'type': 'file', 'url': 'https://dataverse.ucla.edu/api/access/datafile/7786', 'file_id': '7786', 'description': 'AREA85B data in SPSS portable format.', 'published_at': '2019-09- ...
# start: 2930  total: 5067
# "Population Census [South Africa], 1985 (M921V1)",dataset,https://hdl.handle.net/1902.1/M921V1
# https://dataverse.ucla.edu//api/search?q=*&start=2940
