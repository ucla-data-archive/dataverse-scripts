# %%
#  this uses the newest version of pyDataverse
# NOTE:  some parts of the library changed, such as NativeApi for Api

# %%
# interesting problem - sub-dataverse 49 has chinese characters and script blows up there

# %%
# this generates a csv list of the UCLA Dataverse toplevel subdataverses
# example runs but way too many,  just need DOIs and titles, maybe PI
from datetime import datetime
import sys, re, fileinput
import json
import requests  # http://docs.python-requests.org/en/master/
import pyDataverse
from pyDataverse.api import NativeApi
# establish connection
# example runs but way too many,  just need DOIs and titles, maybe PI
import urllib
from urllib.parse import urlparse

outfile = open('D:\work-related\pyDataverse\dvOut2.txt', 'w')
with open('D:\work-related\pyDataverse\dvOut2.csv', "w", encoding="utf-8") as outfile:

    #base = 'https://test.dataverse.ucla.edu'
    base = 'https://dataverse.ucla.edu/'
    #base = 'https://dataverse.harvard.edu/dataverse/ssda_ucla'
    print(base)
    rows = 10
    start = 0
    page = 1
    condition = True # emulate do-while
    outfile = open('D:\work-related\pyDataverse\dataverse-info2.csv', 'w')
    while (condition):
        url = base + '/api/search?q=*' + "&start=" + str(start)
        print(url)
        data = json.load(urllib.request.urlopen(url))   
        print(data)
        total = data['data']['total_count']
        print ("=== Page", page, "===")
        print ("start:", start, " total:", total)
        for i in data['data']['items']:
            if (i['type']) != 'file':
                #print (i['name'] + "," + i['type'])
                line=("\"" + i['name'] + "\"" + "," + i['type']+ "," + i['url'])
                print(line)
                outfile.write(line)
                outfile.write("\n")
    
        start = start + rows
        page += 1
        condition = start < total

    outfile.close()
# Out:
# https://dataverse.ucla.edu/
# https://dataverse.ucla.edu//api/search?q=*&start=0
# {'status': 'OK', 'data': {'q': '*', 'total_count': 5452, 'start': 0, 'spelling_alternatives': {}, 'items': [{'name': 'Karakax Valley Site 4 - Cosmogenic dating results', 'type': 'dataset', 'url': 'https://doi.org/10.25346/S6/LXHDMJ', 'global_id': 'doi:10.25346/S6/LXHDMJ', 'description': 'The file CRN_TableSI_Peltzeretal2020.xlsx is an Excel spreadsheet with the parameters needed to calculate the model ages using the CRONUS online calculator version 3 (https://hess.ess.washington.edu/). The file CRN_Table2_Peltzeretal2020.xlsx is an Excel spreadsheet with the CRN age determination results published in related publication Table 2.', 'published_at': '2020-01-27T23:10:51Z', 'publisher': 'Replication data for: Stable rate of slip along the Karakax section of the Altyn Tagh Fault from observation of inter-glacial and post-glacial offset morphology and surface dating', 'citationHtml': 'PELTZER, GILLES; M&eacute;riaux, Anne-Sophie; van der Woerd, Jerome; Ryerson, Frederick J., 2020, "Karakax Valley Site 4 - Cosmogenic dating results", <a href="https://doi.org/10.25346/S6/LXHDMJ" target="_blank">https://doi.org/10.25346/S6/LXHDMJ</a>, UCLA Dataverse, V1, UNF:6:mbCMpKSC655KHltiDqU6ow== [fileUNF]', 'identifier_of_dataverse': 'atf_kx_landforms_crn_osl', 'name_of_dataverse': 'Replication data for: Stable rate of slip along the Karakax section of the Altyn Tagh Fault from observation of inter-glacial and post-glacial offset morphology and surface dating', 'citation': 'PELTZER, GILLES; Mériaux, Anne-Sophie; van der Woerd, Jerome; Ryerson, Frederick J., 2020, "Karakax Valley Site 4 - Cosmogenic dating results", https://doi.org/10.25346/S6/LXHDMJ, UCLA Dataverse, V1, UNF:6:mbCMpKSC655KHltiDqU6ow== [fileUNF]', 'storageIdentifier': 's3://10.25346/S6/LXHDMJ', 'keywords': ['Cosmogenic Radionuclide dating, Beryllium-10, alluvial terraces, Altyn Tagh Fault, Karakax Valley'], 'subjects': ['Earth and Environmental Sciences'], 'fileCount': 2, 'versionId': 1095, 'versionState': 'RELEASED', 'majorVersion': 1, 'minorVersion': 1, 'createdAt': '2020-01-27T22:53:20Z', 'updatedAt': '2020-04-04T23:53:38Z', 'contacts': [{'name': 'PELTZER, GILLES', 'affiliation': 'University of California, Los Angeles'}, {'name': 'Mériaux Anne-Sophie', 'affiliation': 'Newcastle University, Newcastle Upon Tyne, United Kingdom'}], 'publications': [{'citation': 'Peltzer G., N.D. Brown, A.-S. B. Mériaux, J. van der Woerd, E. J. Rhodes, R.C. Finkel, F.J. Ryerson, J. Hollingsworth, Stable rate of slip along the Karakax section of the Altyn Tagh Fault from observation of inter-glacial and post-glacial offset morphology and surface dating, 2020, Journal of Geophysical Research, doi: 10.1029/2019JB018893.'}, {}], 'geographicCoverage': [{'country': ''}], 'authors': ['PELTZER, GILLES', 'Mériaux, Anne-Sophie', 'van der Woerd, Jerome', 'Ryerson, Frederick J.']}, {'name': 'CRN_Table2_Peltzeretal2020.tab', 'type': 'file', 'url': 'https://dataverse.ucla.edu/api/access/datafile/19560', 'file_id': '19560', 'published_at': '2020-01-27T23:10:51Z', 'file_type': 'Tab-Delimited', 'file_content_type': 'text/tab-separated-values', 'size_in_bytes': 2835, 'md5': 'bf431eb7b9e420b4a28c2237ad6d7139', 'checksum': {'type': 'MD5', 'value': 'bf431eb7b9e420b4a28c2237ad6d7139'}, 'unf': 'UNF:6:l3GKaUmmu6JuDCxmtniZrA==', 'file_persistent_id': 'doi:10.25346/S6/LXHDMJ/UWAK81', 'dataset_name': 'Karakax Valley Site 4 - Cosmogenic dating results', 'dataset_id': '19559', 'dataset_persistent_id': 'doi:10.25346/S6/LXHDMJ', 'dataset_citation': 'PELTZER, GILLES; Mériaux, Anne-Sophie; van der Woerd, Jerome; Ryerson, Frederick J., 2020, "Karakax Valley Site 4 - Cosmogenic dating results", https://doi.org/10.25346/S6/LXHDMJ, UCLA Dataverse, V1, UNF:6:mbCMpKSC655KHltiDqU6ow== [fileUNF]'}, {'name': 'CRN_TableSI_Peltzeretal2020.tab', 'type': 'file', 'url': 'https://dataverse.ucla.edu/api/access/datafile/19561', 'file_id': '19561', 'published_at': '2020-01-27T23:10:51Z', 'file_type': 'Tab-Delimited', 'file_content_type': 'text/tab-s ...
# === Page 1 ===
# start: 0  total: 5452
# "Karakax Valley Site 4 - Cosmogenic dating results",dataset,https://doi.org/10.25346/S6/LXHDMJ
# "Karakax Valley Site 1 - Pleiades Digital Elevation Model",dataset,https://doi.org/10.25346/S6/MSSC65
# "UCLA Registrar Enrollment Data, Winter 1999 - Spring 2020",dataset,https://doi.org/10.25346/S6/LRV0ES
# "Karakax Valley Site 1 - OSL dating results",dataset,https://doi.org/10.25346/S6/NI2QFL
# https://dataverse.ucla.edu//api/search?q=*&start=10
# {'status': 'OK', 'data': {'q': '*', 'total_count': 5452, 'start': 10, 'spelling_alternatives': {}, 'items': [{'name': 'Karakax_Dosimetry_data_DRAC.tab', 'type': 'file', 'url': 'https://dataverse.ucla.edu/api/access/datafile/20385', 'file_id': '20385', 'published_at': '2020-04-05T01:09:03Z', 'file_type': 'Tab-Delimited', 'file_content_type': 'text/tab-separated-values', 'size_in_bytes': 26064, 'md5': 'd3a286e5012694fe55e45dc30be53ded', 'checksum': {'type': 'MD5', 'value': 'd3a286e5012694fe55e45dc30be53ded'}, 'unf': 'UNF:6:SaRfHYJx+2qJZotEqpWPzQ==', 'file_persistent_id': 'doi:10.25346/S6/NI2QFL/X6VT7R', 'dataset_name': 'Karakax Valley Site 1 - OSL dating results', 'dataset_id': '20384', 'dataset_persistent_id': 'doi:10.25346/S6/NI2QFL', 'dataset_citation': 'PELTZER, GILLES; BROWN, NATHAN D., 2020, "Karakax Valley Site 1 - OSL dating results", https://doi.org/10.25346/S6/NI2QFL, UCLA Dataverse, V1, UNF:6:SaRfHYJx+2qJZotEqpWPzQ== [fileUNF]'}, {'name': 'Gapminder Data', 'type': 'dataset', 'url': 'https://doi.org/10.25346/S6/WFC3KG', 'global_id': 'doi:10.25346/S6/WFC3KG', 'description': 'Dataset used for teaching R and Python. [add to this later]', 'published_at': '2020-05-01T23:27:50Z', 'publisher': 'UCLA Data Science Center', 'citationHtml': 'Rosling, Hans, 2020, "Gapminder Data", <a href="https://doi.org/10.25346/S6/WFC3KG" target="_blank">https://doi.org/10.25346/S6/WFC3KG</a>, UCLA Dataverse, V4, UNF:6:NEKJa+hemgnpmRHJMFVKKA== [fileUNF]', 'identifier_of_dataverse': 'dsc', 'name_of_dataverse': 'UCLA Data Science Center', 'citation': 'Rosling, Hans, 2020, "Gapminder Data", https://doi.org/10.25346/S6/WFC3KG, UCLA Dataverse, V4, UNF:6:NEKJa+hemgnpmRHJMFVKKA== [fileUNF]', 'storageIdentifier': 's3://10.25346/S6/WFC3KG', 'subjects': ['Social Sciences'], 'fileCount': 6, 'versionId': 1122, 'versionState': 'RELEASED', 'majorVersion': 4, 'minorVersion': 0, 'createdAt': '2020-04-17T03:31:40Z', 'updatedAt': '2020-05-01T23:27:50Z', 'contacts': [{'name': 'Data Science Center', 'affiliation': 'University of California, Los Angeles'}], 'authors': ['Rosling, Hans']}, {'name': 'gapminder_data.tab', 'type': 'file', 'url': 'https://dataverse.ucla.edu/api/access/datafile/20390', 'file_id': '20390', 'description': 'Gapminder data in csv format', 'published_at': '2020-04-17T03:31:59Z', 'file_type': 'Tab-Delimited', 'file_content_type': 'text/tab-separated-values', 'size_in_bytes': 88634, 'md5': 'dc3083e1af9c6ca80fd7b297188d4f77', 'checksum': {'type': 'MD5', 'value': 'dc3083e1af9c6ca80fd7b297188d4f77'}, 'unf': 'UNF:6:YgJwbX4q7QQs9c3rYlHDSA==', 'file_persistent_id': 'doi:10.25346/S6/WFC3KG/NKM1VN', 'dataset_name': 'Gapminder Data', 'dataset_id': '20389', 'dataset_persistent_id': 'doi:10.25346/S6/WFC3KG', 'dataset_citation': 'Rosling, Hans, 2020, "Gapminder Data", https://doi.org/10.25346/S6/WFC3KG, UCLA Dataverse, V4, UNF:6:NEKJa+hemgnpmRHJMFVKKA== [fileUNF]'}, {'name': 'gapminder-test.ipynb', 'type': 'file', 'url': 'https://dataverse.ucla.edu/api/access/datafile/20456', 'file_id': '20456', 'description': 'jupyter notebook for gapminder data', 'published_at': '2020-05-01T23:15:38Z', 'file_type': 'Jupyter Notebook', 'file_content_type': 'application/x-ipynb+json', 'size_in_bytes': 12142, 'md5': '48648e0193152a7dc00feb8e3263fc11', 'checksum': {'type': 'MD5', 'value': '48648e0193152a7dc00feb8e3263fc11'}, 'file_persistent_id': 'doi:10.25346/S6/WFC3KG/7WMKXX', 'dataset_name': 'Gapminder Data', 'dataset_id': '20389', 'dataset_persistent_id': 'doi:10.25346/S6/WFC3KG', 'dataset_citation': 'Rosling, Hans, 2020, "Gapminder Data", https://doi.org/10.25346/S6/WFC3KG, UCLA Dataverse, V4, UNF:6:NEKJa+hemgnpmRHJMFVKKA== [fileUNF]'}, {'name': 'gapminder_wide.tab', 'type': 'file', 'url': 'https://dataverse.ucla.edu/api/access/datafile/20391', 'file_id': '20391', 'description': 'gapminder data for workshops', 'published_at': '2020-04-17T20:47:00Z', 'file_type': 'Tab-Delimited', 'file_content_type': 'text/tab-separated-values', 'size_in_bytes': 48544, 'md5': '8a1f05738b5 ...
# === Page 2 ===
# start: 10  total: 5452
# "Gapminder Data",dataset,https://doi.org/10.25346/S6/WFC3KG
# "City of Los Angeles: Arrest Data from 2010 to Present",dataset,https://doi.org/10.25346/S6/DE95RT
# https://dataverse.ucla.edu//api/search?q=*&start=20
# {'status': 'OK', 'data': {'q': '*', 'total_count': 5452, 'start': 20, 'spelling_alternatives': {}, 'items': [{'name': 'install.R', 'type': 'file', 'url': 'https://dataverse.ucla.edu/api/access/datafile/20462', 'file_id': '20462', 'description': 'Packages required. ', 'published_at': '2020-05-10T22:12:20Z', 'file_type': 'R Syntax', 'file_content_type': 'type/x-r-syntax', 'size_in_bytes': 60, 'md5': 'ae47562a9614cafcc0e751e9b940a6cd', 'checksum': {'type': 'MD5', 'value': 'ae47562a9614cafcc0e751e9b940a6cd'}, 'file_persistent_id': 'doi:10.25346/S6/DE95RT/Z8XQDA', 'dataset_name': 'City of Los Angeles: Arrest Data from 2010 to Present', 'dataset_id': '20460', 'dataset_persistent_id': 'doi:10.25346/S6/DE95RT', 'dataset_citation': 'Los Angeles Police Department, 2020, "City of Los Angeles: Arrest Data from 2010 to Present", https://doi.org/10.25346/S6/DE95RT, UCLA Dataverse, DRAFT VERSION'}, {'name': 'la_arrests.ipynb', 'type': 'file', 'url': 'https://dataverse.ucla.edu/api/access/datafile/20464', 'file_id': '20464', 'description': 'Jupyter notebook for interacting with the data.', 'published_at': '2020-05-10T22:12:20Z', 'file_type': 'Jupyter Notebook', 'file_content_type': 'application/x-ipynb+json', 'size_in_bytes': 106387, 'md5': 'f9e74b23d2f5967ebb65977efdb8c036', 'checksum': {'type': 'MD5', 'value': 'f9e74b23d2f5967ebb65977efdb8c036'}, 'file_persistent_id': 'doi:10.25346/S6/DE95RT/JAQSDX', 'dataset_name': 'City of Los Angeles: Arrest Data from 2010 to Present', 'dataset_id': '20460', 'dataset_persistent_id': 'doi:10.25346/S6/DE95RT', 'dataset_citation': 'Los Angeles Police Department, 2020, "City of Los Angeles: Arrest Data from 2010 to Present", https://doi.org/10.25346/S6/DE95RT, UCLA Dataverse, DRAFT VERSION'}, {'name': 'runtime.txt', 'type': 'file', 'url': 'https://dataverse.ucla.edu/api/access/datafile/20461', 'file_id': '20461', 'description': 'Specification of R version. ', 'published_at': '2020-05-10T22:12:20Z', 'file_type': 'Plain Text', 'file_content_type': 'text/plain', 'size_in_bytes': 17, 'md5': '2769942ced73613cafee8d3ba5235f98', 'checksum': {'type': 'MD5', 'value': '2769942ced73613cafee8d3ba5235f98'}, 'file_persistent_id': 'doi:10.25346/S6/DE95RT/5LMPHE', 'dataset_name': 'City of Los Angeles: Arrest Data from 2010 to Present', 'dataset_id': '20460', 'dataset_persistent_id': 'doi:10.25346/S6/DE95RT', 'dataset_citation': 'Los Angeles Police Department, 2020, "City of Los Angeles: Arrest Data from 2010 to Present", https://doi.org/10.25346/S6/DE95RT, UCLA Dataverse, DRAFT VERSION'}, {'name': 'Tim Dennis Dataverse', 'type': 'dataverse', 'url': 'https://dataverse.ucla.edu/dataverse/timdennis', 'identifier': 'timdennis', 'description': "Tim's dataverse", 'published_at': '2020-05-10T22:12:20Z'}, {'name': 'Spring 2020 R Workshop', 'type': 'dataset', 'url': 'https://doi.org/10.25346/S6/ZJKUAC', 'global_id': 'doi:10.25346/S6/ZJKUAC', 'description': 'Data Science Center remote workshops', 'published_at': '2020-05-15T15:52:00Z', 'publisher': 'UCLA Data Science Center', 'citationHtml': 'Data Science Center; Jamison, Jamie; Allen, Kristian; Phan, Leigh, 2020, "Spring 2020 R Workshop", <a href="https://doi.org/10.25346/S6/ZJKUAC" target="_blank">https://doi.org/10.25346/S6/ZJKUAC</a>, UCLA Dataverse, V9', 'identifier_of_dataverse': 'dsc', 'name_of_dataverse': 'UCLA Data Science Center', 'citation': 'Data Science Center; Jamison, Jamie; Allen, Kristian; Phan, Leigh, 2020, "Spring 2020 R Workshop", https://doi.org/10.25346/S6/ZJKUAC, UCLA Dataverse, V9', 'storageIdentifier': 's3://10.25346/S6/ZJKUAC', 'subjects': ['Computer and Information Science'], 'fileCount': 6, 'versionId': 1126, 'versionState': 'RELEASED', 'majorVersion': 9, 'minorVersion': 0, 'createdAt': '2020-04-20T18:19:52Z', 'updatedAt': '2020-05-23T16:50:39Z', 'contacts': [{'name': 'Data Science Center', 'affiliation': 'University of California, Los Angeles'}], 'publications': [{'citation': 'Jamie Jamison, Kristian Allen, Leigh Phan, Tim Dennis, (2020, April). ucla-data ...
# === Page 3 ===
# start: 20  total: 5452
# "Tim Dennis Dataverse",dataverse,https://dataverse.ucla.edu/dataverse/timdennis
# "Spring 2020 R Workshop",dataset,https://doi.org/10.25346/S6/ZJKUAC
# https://dataverse.ucla.edu//api/search?q=*&start=30
# {'status': 'OK', 'data': {'q': '*', 'total_count': 5452, 'start': 30, 'spelling_alternatives': {}, 'items': [{'name': '2020-05-01-rmarkdown-part1.mp4', 'type': 'file', 'url': 'https://dataverse.ucla.edu/api/access/datafile/20468', 'file_id': '20468', 'description': 'Part 1 of the R Markdown. ', 'published_at': '2020-05-15T15:52:00Z', 'file_type': 'MPEG-4 Video', 'file_content_type': 'video/mp4', 'size_in_bytes': 137066641, 'md5': '2910ba2bfdad4bc18b583abae440dccf', 'checksum': {'type': 'MD5', 'value': '2910ba2bfdad4bc18b583abae440dccf'}, 'file_persistent_id': 'doi:10.25346/S6/ZJKUAC/GFYAHH', 'dataset_name': 'Spring 2020 R Workshop', 'dataset_id': '20392', 'dataset_persistent_id': 'doi:10.25346/S6/ZJKUAC', 'dataset_citation': 'Data Science Center; Jamison, Jamie; Allen, Kristian; Phan, Leigh, 2020, "Spring 2020 R Workshop", https://doi.org/10.25346/S6/ZJKUAC, UCLA Dataverse, V9'}, {'name': 'Association of work-family experience with mid- and late-life memory decline in US women - Supplementary File', 'type': 'dataset', 'url': 'https://doi.org/10.25346/S6/ZR9FRC', 'global_id': 'doi:10.25346/S6/ZR9FRC', 'description': 'Supplementary file for manuscript "Association of work-family experience with mid- and late-life memory decline in US women"', 'published_at': '2020-06-03T01:02:49Z', 'publisher': 'Mayeda Research Group Dataverse', 'citationHtml': 'Mayeda, Elizabeth Rose; Mobley, Taylor M.; Weiss, Robert E.; Murchland, Audrey R.; Berkman, Lisa F.; Sabbath, Erika L., 2020, "Association of work-family experience with mid- and late-life memory decline in US women - Supplementary File", <a href="https://doi.org/10.25346/S6/ZR9FRC" target="_blank">https://doi.org/10.25346/S6/ZR9FRC</a>, UCLA Dataverse, V1', 'identifier_of_dataverse': 'mayeda', 'name_of_dataverse': 'Mayeda Research Group Dataverse', 'citation': 'Mayeda, Elizabeth Rose; Mobley, Taylor M.; Weiss, Robert E.; Murchland, Audrey R.; Berkman, Lisa F.; Sabbath, Erika L., 2020, "Association of work-family experience with mid- and late-life memory decline in US women - Supplementary File", https://doi.org/10.25346/S6/ZR9FRC, UCLA Dataverse, V1', 'storageIdentifier': 's3://10.25346/S6/ZR9FRC', 'subjects': ['Medicine, Health and Life Sciences'], 'fileCount': 1, 'versionId': 1130, 'versionState': 'RELEASED', 'majorVersion': 1, 'minorVersion': 0, 'createdAt': '2020-06-03T00:56:19Z', 'updatedAt': '2020-06-03T01:02:49Z', 'contacts': [{'name': 'Mayeda, Elizabeth Rose', 'affiliation': 'University of California, Los Angeles Fielding School of Public Health'}, {'name': 'Mobley, Taylor M.', 'affiliation': 'University of California, Los Angeles Fielding School of Public Health'}], 'authors': ['Mayeda, Elizabeth Rose', 'Mobley, Taylor M.', 'Weiss, Robert E.', 'Murchland, Audrey R.', 'Berkman, Lisa F.', 'Sabbath, Erika L.']}, {'name': 'Mayeda_work_family_experience_memory_decline_supplemental_file.pdf', 'type': 'file', 'url': 'https://dataverse.ucla.edu/api/access/datafile/20474', 'file_id': '20474', 'published_at': '2020-06-03T01:02:49Z', 'file_type': 'Adobe PDF', 'file_content_type': 'application/pdf', 'size_in_bytes': 1214393, 'md5': '89c36b8c542c1d9478ba83fcf599ec86', 'checksum': {'type': 'MD5', 'value': '89c36b8c542c1d9478ba83fcf599ec86'}, 'file_persistent_id': 'doi:10.25346/S6/ZR9FRC/BIRQOC', 'dataset_name': 'Association of work-family experience with mid- and late-life memory decline in US women - Supplementary File', 'dataset_id': '20473', 'dataset_persistent_id': 'doi:10.25346/S6/ZR9FRC', 'dataset_citation': 'Mayeda, Elizabeth Rose; Mobley, Taylor M.; Weiss, Robert E.; Murchland, Audrey R.; Berkman, Lisa F.; Sabbath, Erika L., 2020, "Association of work-family experience with mid- and late-life memory decline in US women - Supplementary File", https://doi.org/10.25346/S6/ZR9FRC, UCLA Dataverse, V1'}, {'name': 'TIMOTHY TANGHERLINI Dataverse', 'type': 'dataverse', 'url': 'https://dataverse.ucla.edu/dataverse/tango', 'identifier': 'tango', 'published_at': '2020-05-19T05:53:58Z'}, {'name': ...
# === Page 4 ===
# start: 30  total: 5452
# "Association of work-family experience with mid- and late-life memory decline in US women - Supplementary File",dataset,https://doi.org/10.25346/S6/ZR9FRC
# "TIMOTHY TANGHERLINI Dataverse",dataverse,https://dataverse.ucla.edu/dataverse/tango
# "Mayeda Research Group Dataverse",dataverse,https://dataverse.ucla.edu/dataverse/mayeda
# "Jamie Jamison",dataverse,https://dataverse.ucla.edu/dataverse/jmjtest
# "UCLA Library Data Archive",dataverse,https://dataverse.ucla.edu/dataverse/ucla_dataarchive
# "Dye Plant Class Material",dataverse,https://dataverse.ucla.edu/dataverse/jmj-dye-plant-class
# "Bill and Melinda Gates Foundation Data",dataverse,https://dataverse.ucla.edu/dataverse/gates-foundation
# "Replication data for: Stable rate of slip along the Karakax section of the Altyn Tagh Fault from observation of inter-glacial and post-glacial offset morphology and surface dating",dataverse,https://dataverse.ucla.edu/dataverse/atf_kx_landforms_crn_osl
# https://dataverse.ucla.edu//api/search?q=*&start=40
# {'status': 'OK', 'data': {'q': '*', 'total_count': 5452, 'start': 40, 'spelling_alternatives': {}, 'items': [{'name': 'NATHAN SMITH Dataverse', 'type': 'dataverse', 'url': 'https://dataverse.ucla.edu/dataverse/nathan-smith', 'identifier': 'nathan-smith', 'published_at': '2020-03-18T17:45:38Z'}, {'name': 'Social Science Data Archive', 'type': 'dataverse', 'url': 'https://dataverse.ucla.edu/dataverse/ssda_ucla', 'identifier': 'ssda_ucla', 'description': 'The Social Science Data Archive has been operating at UCLA since 1961 when political science professor Dwaine Marvick established the Political Behavior Archive (PBA); through his efforts, UCLA was one of the 8 founding members of the Inter-university Consortium for Political and Social Research (ICPSR) in 1962. When the Survey Research Center (SRC) was formed in 1964, under the direction of Eve Fielder, the PBA was merged with a planned Archive Data Library the SRC was to house. In 1977, the research support framework of the Data Archive was designed by Professor Donald Treiman and implemented until it was re-organized into the UCLA Library in 2014. The mission of the Social Science Data Archive has been and continues to be to provide a foundation for social science research with faculty support throughout an entire research project involving original data collection or the reuse of publicly available studies. Data Archive staff and researchers work as partners throughout all stages of the research process, beginning when a hypothesis or area of study is being developed, during grant and funding activities, while data collection and/or analysis is ongoing, and finally in long term preservation of research results. Our role is to provide a collaborative environment where the focus is on understanding the nature and scope of research approach and management of research output throughout the entire life cycle of the project. Our Dataverse consists of unique surveys, enumerations, public opinion polls, and de-identified administrative records. Topics of studies include political attitudes and behavior; social and economic attitudes and behaviors; studies of health status and health outcomes; families, children, and women; international surveys of occupational and social mobility; the Los Angeles County Social Surveys; California Polls; and, census data for the United States and other countries. In addition, the SSDA provides access to data from the Inter-university Consortium for Political and Social Research and the Roper Center for Public Opinion Research. Materials from SSDA are used with software programs, such as SPSS, SAS, STATA, and R to carry out statistical analysis. Assistance in using statistical packages is provided by the IDRE Statistical consulting office. Instructional support, especially support that links research with instruction is also a mainstay of operations. The Data Archive is one of the key support components in those disciplines that provide instruction in research methods, survey design and methods, statistics, and data analysis. Throughout the campus, data provided by the Archive is used by faculty in courses to transmit pedagogy, illustrate theory and develop understanding of social, political, demographic, economic, geographic and historical trends and issues. throughout the entire life cycle of the project. Our Dataverse contains resources to help you find and analyze data, and tutorials to enrich your knowledge of data management practices and procedures. We provide advice in preparing data management plans and in applying for access to secure or restricted access datasets. If you are interested in sharing your data and need assistance in finding an appropriate archive, or would like help to document your data for the purpose of sharing, please contact us. For more information, see our Dataverse on Tutorials and Resources.', 'published_at': '2018-09-28T22:42:16Z'}, {'name': 'Gates Open Access Publishing Charges Project', 'type': 'dataset', 'url': 'ht ...
# === Page 5 ===
# start: 40  total: 5452
# "NATHAN SMITH Dataverse",dataverse,https://dataverse.ucla.edu/dataverse/nathan-smith
# "Social Science Data Archive",dataverse,https://dataverse.ucla.edu/dataverse/ssda_ucla
# "Gates Open Access Publishing Charges Project",dataset,https://doi.org/10.25346/S6/EEFYIP
# "UCLA Open Archive",dataverse,https://dataverse.ucla.edu/dataverse/ucla_openarchive
# "test after aws move",dataverse,https://dataverse.ucla.edu/dataverse/post-move-test2
# "direct upload test DEM",dataset,https://doi.org/10.25346/S6/UJOJHE
# https://dataverse.ucla.edu//api/search?q=*&start=50
# {'status': 'OK', 'data': {'q': '*', 'total_count': 5452, 'start': 50, 'spelling_alternatives': {}, 'items': [{'name': 'unit08.gdb.zip', 'type': 'file', 'url': 'https://dataverse.ucla.edu/api/access/datafile/20819', 'file_id': '20819', 'description': 'geodatabase test file', 'published_at': '2020-06-09T19:38:34Z', 'file_type': 'ZIP Archive', 'file_content_type': 'application/zip', 'size_in_bytes': 72434223, 'md5': 'b77b5eb3fa1e46d0a5be88493348fc2b', 'checksum': {'type': 'MD5', 'value': 'b77b5eb3fa1e46d0a5be88493348fc2b'}, 'file_persistent_id': 'doi:10.25346/S6/UJOJHE/L8L3B0', 'dataset_name': 'direct upload test DEM', 'dataset_id': '20479', 'dataset_persistent_id': 'doi:10.25346/S6/UJOJHE', 'dataset_citation': 'JAMISON, JINA, 2020, "direct upload test DEM", https://doi.org/10.25346/S6/UJOJHE, UCLA Dataverse, V3'}, {'name': 'Rapid Analytical Instrumentation for Electrochemical Impedance Spectroscopy Measurements', 'type': 'dataset', 'url': 'https://doi.org/10.25346/S6/WDRBKE', 'global_id': 'doi:10.25346/S6/WDRBKE', 'description': 'This work reports a low-cost custom electrochemical instrument capable of performing rapid and accurate electrochemical impedance spectroscopy (EIS) for supercapacitors over a broad frequency band (10 mHz to 2 kHz). Conventionally, EIS is measured via sinusoidal perturbations; however, such an approach suffers from lengthy measurement time. Chirp signals have been shown previously to reduce EIS measurement time for supercapacitors for relative narrow frequency bands (1 Hz to 2 kHz). However, to characterize supercapacitors comprehensively, much broader frequency bands are required. Here, we present a custom instrument with an adaptive measurement algorithm for performing EIS measurements in a wide frequency range of 10 mHz to 2 kHz with low measurement uncertainties. The results obtained using this new technique has been validated here with a commercial instrument on several types of supercapacitors. Furthermore, measurement time on average decreases from 1500 s to less than 400 s. The overall cost of the custom instrument is 90% lower as compared to the commercial instrument. The custom instrument’s accuracy, time efficiency and low cost are expected to benefit electrochemical researchers.', 'published_at': '2020-07-15T20:41:27Z', 'publisher': 'UCLA Mechanical & Aerospace Engineering', 'citationHtml': 'Hu, Yuan; Brahim, Sean; Maat, Stefan; Davies, Patricia; Kundu, Arpan; Fisher, Timothy S., 2020, "Rapid Analytical Instrumentation for Electrochemical Impedance Spectroscopy Measurements", <a href="https://doi.org/10.25346/S6/WDRBKE" target="_blank">https://doi.org/10.25346/S6/WDRBKE</a>, UCLA Dataverse, V1', 'identifier_of_dataverse': 'mae', 'name_of_dataverse': 'UCLA Mechanical & Aerospace Engineering', 'citation': 'Hu, Yuan; Brahim, Sean; Maat, Stefan; Davies, Patricia; Kundu, Arpan; Fisher, Timothy S., 2020, "Rapid Analytical Instrumentation for Electrochemical Impedance Spectroscopy Measurements", https://doi.org/10.25346/S6/WDRBKE, UCLA Dataverse, V1', 'storageIdentifier': 's3://10.25346/S6/WDRBKE', 'subjects': ['Engineering'], 'fileCount': 3, 'versionId': 1151, 'versionState': 'RELEASED', 'majorVersion': 1, 'minorVersion': 0, 'createdAt': '2020-07-14T23:21:17Z', 'updatedAt': '2020-07-15T20:41:27Z', 'contacts': [{'name': '', 'affiliation': ''}], 'publications': [{}], 'authors': ['Hu, Yuan', 'Brahim, Sean', 'Maat, Stefan', 'Davies, Patricia', 'Kundu, Arpan', 'Fisher, Timothy S.']}, {'name': 'demo_variational_chirp.csv', 'type': 'file', 'url': 'https://dataverse.ucla.edu/api/access/datafile/20841', 'file_id': '20841', 'published_at': '2020-07-15T20:41:27Z', 'file_type': 'Comma Separated Values', 'file_content_type': 'text/csv', 'size_in_bytes': 7473, 'md5': '2625dd14f8b7a03c626ee0779bec0a21', 'checksum': {'type': 'MD5', 'value': '2625dd14f8b7a03c626ee0779bec0a21'}, 'file_persistent_id': 'doi:10.25346/S6/WDRBKE/IYTSZN', 'dataset_name': 'Rapid Analytical Instrumentation for Electrochemical Impedance Spe ...
# === Page 6 ===
# start: 50  total: 5452
# "Rapid Analytical Instrumentation for Electrochemical Impedance Spectroscopy Measurements",dataset,https://doi.org/10.25346/S6/WDRBKE
# "UCLA Mechanical & Aerospace Engineering",dataverse,https://dataverse.ucla.edu/dataverse/mae
# "UCLA Data Science Center",dataverse,https://dataverse.ucla.edu/dataverse/dsc
# "LARIAC5",dataverse,https://dataverse.ucla.edu/dataverse/lariac5
# "Reports: Accuracy Assessment",dataset,https://doi.org/10.25346/S6/HOFGDJ
# https://dataverse.ucla.edu//api/search?q=*&start=60
# {'status': 'OK', 'data': {'q': '*', 'total_count': 5452, 'start': 60, 'spelling_alternatives': {}, 'items': [{'name': 'Shapefiles.zip', 'type': 'file', 'url': 'https://dataverse.ucla.edu/api/access/datafile/21064', 'file_id': '21064', 'description': 'Shape files: Ortho Imagery Grid', 'published_at': '2020-09-03T19:21:01Z', 'file_type': 'ZIP Archive', 'file_content_type': 'application/zip', 'size_in_bytes': 388969, 'md5': 'd7f012db9a02c1f365cb26c735932d29', 'checksum': {'type': 'MD5', 'value': 'd7f012db9a02c1f365cb26c735932d29'}, 'file_persistent_id': 'doi:10.25346/S6/HOFGDJ/60ACHA', 'dataset_name': 'Reports: Accuracy Assessment', 'dataset_id': '20628', 'dataset_persistent_id': 'doi:10.25346/S6/HOFGDJ', 'dataset_citation': 'JAMISON, JINA, 2020, "Reports: Accuracy Assessment", https://doi.org/10.25346/S6/HOFGDJ, UCLA Dataverse, V6'}, {'name': 'Association of work-family experience with mid- and late-life memory decline in US women - Supplementary File', 'type': 'dataset', 'url': 'https://doi.org/10.25346/S6/UKL1KC', 'global_id': 'doi:10.25346/S6/UKL1KC', 'description': 'Supplemental file for manuscript "Association of work-family experience with mid- and late-life memory decline in US women"', 'published_at': '2020-07-14T17:57:52Z', 'publisher': 'UCLA Dataverse', 'citationHtml': 'MAYEDA, ELIZABETH ROSE; MOBLEY, TAYLOR M.; WEISS, ROBERT E.; MURCHLAND, AUDREY R.; BERKMAN, LISA F.; SABBATH, ERIKA L., 2020, "Association of work-family experience with mid- and late-life memory decline in US women - Supplementary File", <a href="https://doi.org/10.25346/S6/UKL1KC" target="_blank">https://doi.org/10.25346/S6/UKL1KC</a>, UCLA Dataverse, V1', 'identifier_of_dataverse': 'ucla', 'name_of_dataverse': 'UCLA Dataverse', 'citation': 'MAYEDA, ELIZABETH ROSE; MOBLEY, TAYLOR M.; WEISS, ROBERT E.; MURCHLAND, AUDREY R.; BERKMAN, LISA F.; SABBATH, ERIKA L., 2020, "Association of work-family experience with mid- and late-life memory decline in US women - Supplementary File", https://doi.org/10.25346/S6/UKL1KC, UCLA Dataverse, V1', 'storageIdentifier': 's3://10.25346/S6/UKL1KC', 'subjects': ['Medicine, Health and Life Sciences'], 'fileCount': 1, 'versionId': 1129, 'versionState': 'RELEASED', 'majorVersion': 1, 'minorVersion': 0, 'createdAt': '2020-06-02T22:31:39Z', 'updatedAt': '2020-07-14T17:57:52Z', 'contacts': [{'name': 'MAYEDA, ELIZABETH ROSE', 'affiliation': 'University of California, Los Angeles'}, {'name': 'MOBLEY, TAYLOR', 'affiliation': 'University of California, Los Angeles'}], 'publications': [{}], 'geographicCoverage': [{'country': ''}], 'authors': ['MAYEDA, ELIZABETH ROSE', 'MOBLEY, TAYLOR M.', 'WEISS, ROBERT E.', 'MURCHLAND, AUDREY R.', 'BERKMAN, LISA F.', 'SABBATH, ERIKA L.']}, {'name': 'Mayeda_work_family_experience_memory_decline_supplemental_file.pdf', 'type': 'file', 'url': 'https://dataverse.ucla.edu/api/access/datafile/20471', 'file_id': '20471', 'published_at': '2020-07-14T17:57:52Z', 'file_type': 'Adobe PDF', 'file_content_type': 'application/pdf', 'size_in_bytes': 1214393, 'md5': '89c36b8c542c1d9478ba83fcf599ec86', 'checksum': {'type': 'MD5', 'value': '89c36b8c542c1d9478ba83fcf599ec86'}, 'file_persistent_id': 'doi:10.25346/S6/UKL1KC/HORFNF', 'dataset_name': 'Association of work-family experience with mid- and late-life memory decline in US women - Supplementary File', 'dataset_id': '20470', 'dataset_persistent_id': 'doi:10.25346/S6/UKL1KC', 'dataset_citation': 'MAYEDA, ELIZABETH ROSE; MOBLEY, TAYLOR M.; WEISS, ROBERT E.; MURCHLAND, AUDREY R.; BERKMAN, LISA F.; SABBATH, ERIKA L., 2020, "Association of work-family experience with mid- and late-life memory decline in US women - Supplementary File", https://doi.org/10.25346/S6/UKL1KC, UCLA Dataverse, V1'}, {'name': 'Ortho Imagery Grid Shapefile', 'type': 'dataset', 'url': 'https://doi.org/10.25346/S6/XZ36OQ', 'global_id': 'doi:10.25346/S6/XZ36OQ', 'description': 'Ortho Imagery Grid Shapefile in Zipped format.', 'published_at': '2020-09-03T21:30:23Z', 'publisher': 'LARIAC5', 'citati ...
# === Page 7 ===
# start: 60  total: 5452
# "Association of work-family experience with mid- and late-life memory decline in US women - Supplementary File",dataset,https://doi.org/10.25346/S6/UKL1KC
# "Ortho Imagery Grid Shapefile",dataset,https://doi.org/10.25346/S6/XZ36OQ
# "Brain Volume Fractions Across Mammals with Relation to Behavior in Carnivores, Primates, Ungulates, and Rodents Data",dataset,https://doi.org/10.25346/S6/GKSJCU
# "Paloma and Associates Open Access Cost Transparency Project Replication Data",dataset,https://doi.org/10.25346/S6/VODY5G
# https://dataverse.ucla.edu//api/search?q=*&start=70
# {'status': 'OK', 'data': {'q': '*', 'total_count': 5452, 'start': 70, 'spelling_alternatives': {}, 'items': [{'name': 'Paloma APC Transparency Project Gates Invoices 1 July 2016 to 31 March 2019  Research Dataset Codebook.pdf', 'type': 'file', 'url': 'https://dataverse.ucla.edu/api/access/datafile/19502', 'file_id': '19502', 'description': 'Codebook in PDF format', 'published_at': '2019-10-31T23:44:14Z', 'file_type': 'Adobe PDF', 'file_content_type': 'application/pdf', 'size_in_bytes': 77642, 'md5': '09cd68ae5c60d868043367f204ce5064', 'checksum': {'type': 'MD5', 'value': '09cd68ae5c60d868043367f204ce5064'}, 'file_persistent_id': 'doi:10.25346/S6/VODY5G/L7WMIQ', 'dataset_name': 'Paloma and Associates Open Access Cost Transparency Project Replication Data', 'dataset_id': '19496', 'dataset_persistent_id': 'doi:10.25346/S6/VODY5G', 'dataset_citation': 'Dove, John G., 2019, "Paloma and Associates Open Access Cost Transparency Project Replication Data", https://doi.org/10.25346/S6/VODY5G, UCLA Dataverse, V2, UNF:6:XpFCGvW+rOgtNoxHtJ5tZQ== [fileUNF]'}, {'name': 'Paloma APC Transparency Project Gates Invoices 1 July 2016 to 31 March 2019  Research Dataset.tab', 'type': 'file', 'url': 'https://dataverse.ucla.edu/api/access/datafile/19498', 'file_id': '19498', 'description': 'Data in CSV format', 'published_at': '2019-10-31T23:44:14Z', 'file_type': 'Tab-Delimited', 'file_content_type': 'text/tab-separated-values', 'size_in_bytes': 1079011, 'md5': '6c43a6e02e06227ca1ddf0540fb709ea', 'checksum': {'type': 'MD5', 'value': '6c43a6e02e06227ca1ddf0540fb709ea'}, 'unf': 'UNF:6:XpFCGvW+rOgtNoxHtJ5tZQ==', 'file_persistent_id': 'doi:10.25346/S6/VODY5G/5EKJEL', 'dataset_name': 'Paloma and Associates Open Access Cost Transparency Project Replication Data', 'dataset_id': '19496', 'dataset_persistent_id': 'doi:10.25346/S6/VODY5G', 'dataset_citation': 'Dove, John G., 2019, "Paloma and Associates Open Access Cost Transparency Project Replication Data", https://doi.org/10.25346/S6/VODY5G, UCLA Dataverse, V2, UNF:6:XpFCGvW+rOgtNoxHtJ5tZQ== [fileUNF]'}, {'name': 'Intro to R Workshop: Collaboratory', 'type': 'dataset', 'url': 'https://doi.org/10.25346/S6/KEBT2O', 'global_id': 'doi:10.25346/S6/KEBT2O', 'description': 'These are the course materials for the Intro to R workshop taught by Ibraheem for the Collaboratory Workshop series as part of Applied Bioinformatics M275A and Molecular, Cellular and Developmental Biology MCDB199.', 'published_at': '2020-11-13T21:31:34Z', 'publisher': "Ibraheem Ali's Dataverse", 'citationHtml': 'ALI, IBRAHEEM, 2020, "Intro to R Workshop: Collaboratory", <a href="https://doi.org/10.25346/S6/KEBT2O" target="_blank">https://doi.org/10.25346/S6/KEBT2O</a>, UCLA Dataverse, V1, UNF:6:j6vyXWNHQ1vSQVtcA819ug== [fileUNF]', 'identifier_of_dataverse': 'iali', 'name_of_dataverse': "Ibraheem Ali's Dataverse", 'citation': 'ALI, IBRAHEEM, 2020, "Intro to R Workshop: Collaboratory", https://doi.org/10.25346/S6/KEBT2O, UCLA Dataverse, V1, UNF:6:j6vyXWNHQ1vSQVtcA819ug== [fileUNF]', 'storageIdentifier': 's3://10.25346/S6/KEBT2O', 'keywords': ['Class Materials', 'R Programming', 'Data Visualization', 'Bioinformatics', 'Computation'], 'subjects': ['Computer and Information Science', 'Medicine, Health and Life Sciences'], 'fileCount': 7, 'versionId': 1207, 'versionState': 'RELEASED', 'majorVersion': 1, 'minorVersion': 0, 'createdAt': '2020-11-13T21:25:38Z', 'updatedAt': '2020-11-13T21:31:34Z', 'contacts': [{'name': 'ALI, IBRAHEEM', 'affiliation': 'University of California, Los Angeles'}], 'publications': [{'url': 'https://github.com/ibsali33/IntroToR-1'}], 'geographicCoverage': [{'country': ''}], 'authors': ['ALI, IBRAHEEM']}, {'name': '201027-IntroToR.Rproj', 'type': 'file', 'url': 'https://dataverse.ucla.edu/api/access/datafile/21704', 'file_id': '21704', 'description': 'R project file', 'published_at': '2020-11-13T21:31:34Z', 'file_type': 'Unknown', 'file_content_type': 'application/octet-stream', 'size_in_bytes': 205, 'md5': 'c8d3f84a410f46d4d8b ...
# === Page 8 ===
# start: 70  total: 5452
# "Intro to R Workshop: Collaboratory",dataset,https://doi.org/10.25346/S6/KEBT2O
# https://dataverse.ucla.edu//api/search?q=*&start=80
# {'status': 'OK', 'data': {'q': '*', 'total_count': 5452, 'start': 80, 'spelling_alternatives': {}, 'items': [{'name': "Ibraheem Ali's Dataverse", 'type': 'dataverse', 'url': 'https://dataverse.ucla.edu/dataverse/iali', 'identifier': 'iali', 'description': "This dataverse contains instructional materials and data sets for Dr. Ibraheem Ali's research projects.", 'published_at': '2020-11-13T21:10:33Z'}, {'name': 'Isotopologue_data_reduction_Green_Bank', 'type': 'dataset', 'url': 'https://doi.org/10.25346/S6/9PSYUU', 'global_id': 'doi:10.25346/S6/9PSYUU', 'description': 'Data reduction and analysis code for SiO isotopologue ratios using the Green Bank Telescope. Software written by Dr. Nate Monson.', 'published_at': '2020-11-20T21:08:55Z', 'publisher': 'YOUNG LAB Dataverse', 'citationHtml': 'YOUNG, EDWARD, 2020, "Isotopologue_data_reduction_Green_Bank", <a href="https://doi.org/10.25346/S6/9PSYUU" target="_blank">https://doi.org/10.25346/S6/9PSYUU</a>, UCLA Dataverse, V1', 'identifier_of_dataverse': 'Young_Lab', 'name_of_dataverse': 'YOUNG LAB Dataverse', 'citation': 'YOUNG, EDWARD, 2020, "Isotopologue_data_reduction_Green_Bank", https://doi.org/10.25346/S6/9PSYUU, UCLA Dataverse, V1', 'storageIdentifier': 's3://10.25346/S6/9PSYUU', 'keywords': ['Radio Astronomy'], 'subjects': ['Earth and Environmental Sciences', 'Physics'], 'fileCount': 1, 'versionId': 1209, 'versionState': 'RELEASED', 'majorVersion': 1, 'minorVersion': 0, 'createdAt': '2020-11-20T20:06:55Z', 'updatedAt': '2020-11-20T21:08:55Z', 'contacts': [{'name': 'YOUNG, EDWARD', 'affiliation': 'University of California, Los Angeles'}], 'publications': [{'citation': 'Monson N.N.*, Morris M.R., and Young E.D. (2017) Uniform silicon isotope ratios across the Milky Way Galaxy. The Astrophysical Journal 839, doi.org/10.3847/1538-4357/aa67e6.', 'url': 'https://faculty.epss.ucla.edu/~eyoung/reprints/Monson_etal_2017.pdf'}], 'authors': ['YOUNG, EDWARD']}, {'name': 'Hydra.pdf', 'type': 'file', 'url': 'https://dataverse.ucla.edu/api/access/datafile/21721', 'file_id': '21721', 'description': 'PDF description of code and IDL source.', 'published_at': '2020-11-20T21:08:55Z', 'file_type': 'Adobe PDF', 'file_content_type': 'application/pdf', 'size_in_bytes': 379993, 'md5': '7b59bb0320d39f159f01bc0a1f1fe5e7', 'checksum': {'type': 'MD5', 'value': '7b59bb0320d39f159f01bc0a1f1fe5e7'}, 'file_persistent_id': 'doi:10.25346/S6/9PSYUU/I0STXX', 'dataset_name': 'Isotopologue_data_reduction_Green_Bank', 'dataset_id': '21720', 'dataset_persistent_id': 'doi:10.25346/S6/9PSYUU', 'dataset_citation': 'YOUNG, EDWARD, 2020, "Isotopologue_data_reduction_Green_Bank", https://doi.org/10.25346/S6/9PSYUU, UCLA Dataverse, V1'}, {'name': 'YOUNG LAB Dataverse', 'type': 'dataverse', 'url': 'https://dataverse.ucla.edu/dataverse/Young_Lab', 'identifier': 'Young_Lab', 'description': 'Archive for Young Laboratory at UCLA.', 'published_at': '2020-11-20T20:07:35Z'}, {'name': '20190502redraw', 'type': 'dataset', 'url': 'https://doi.org/10.25346/S6/9BIIIH', 'global_id': 'doi:10.25346/S6/9BIIIH', 'description': '2019-05-02 (UT)', 'published_at': '2020-11-20T21:10:43Z', 'publisher': 'GMOS', 'citationHtml': 'KLEIN, BETH, 2020, "20190502redraw", <a href="https://doi.org/10.25346/S6/9BIIIH" target="_blank">https://doi.org/10.25346/S6/9BIIIH</a>, UCLA Dataverse, V1', 'identifier_of_dataverse': 'ucla_whitedwarf_gmos', 'name_of_dataverse': 'GMOS', 'citation': 'KLEIN, BETH, 2020, "20190502redraw", https://doi.org/10.25346/S6/9BIIIH, UCLA Dataverse, V1', 'storageIdentifier': 's3://10.25346/S6/9BIIIH', 'subjects': ['Astronomy and Astrophysics'], 'fileCount': 118, 'versionId': 1206, 'versionState': 'RELEASED', 'majorVersion': 1, 'minorVersion': 0, 'createdAt': '2020-11-08T20:18:35Z', 'updatedAt': '2020-11-20T21:10:43Z', 'contacts': [{'name': 'KLEIN, BETH', 'affiliation': 'University of California, Los Angeles'}], 'authors': ['KLEIN, BETH']}, {'name': 'arc.list', 'type': 'file', 'url': 'https://dataverse.ucla.edu/api/access/datafile/2158 ...
# === Page 9 ===
# start: 80  total: 5452
# "Ibraheem Ali's Dataverse",dataverse,https://dataverse.ucla.edu/dataverse/iali
# "Isotopologue_data_reduction_Green_Bank",dataset,https://doi.org/10.25346/S6/9PSYUU
# "YOUNG LAB Dataverse",dataverse,https://dataverse.ucla.edu/dataverse/Young_Lab
# "20190502redraw",dataset,https://doi.org/10.25346/S6/9BIIIH
# https://dataverse.ucla.edu//api/search?q=*&start=90
# {'status': 'OK', 'data': {'q': '*', 'total_count': 5452, 'start': 90, 'spelling_alternatives': {}, 'items': [{'name': 'flat_in.list', 'type': 'file', 'url': 'https://dataverse.ucla.edu/api/access/datafile/21584', 'file_id': '21584', 'published_at': '2020-11-20T21:10:43Z', 'file_type': 'Plain Text', 'file_content_type': 'text/plain', 'size_in_bytes': 339, 'md5': 'c150da602e89fceb7f2f72ef64beed59', 'checksum': {'type': 'MD5', 'value': 'c150da602e89fceb7f2f72ef64beed59'}, 'file_persistent_id': 'doi:10.25346/S6/9BIIIH/27RASH', 'dataset_name': '20190502redraw', 'dataset_id': '21579', 'dataset_persistent_id': 'doi:10.25346/S6/9BIIIH', 'dataset_citation': 'KLEIN, BETH, 2020, "20190502redraw", https://doi.org/10.25346/S6/9BIIIH, UCLA Dataverse, V1'}, {'name': 'flat.list', 'type': 'file', 'url': 'https://dataverse.ucla.edu/api/access/datafile/21580', 'file_id': '21580', 'published_at': '2020-11-20T21:10:43Z', 'file_type': 'Plain Text', 'file_content_type': 'text/plain', 'size_in_bytes': 1540, 'md5': 'c1774a81708ec5d830aa52076521f116', 'checksum': {'type': 'MD5', 'value': 'c1774a81708ec5d830aa52076521f116'}, 'file_persistent_id': 'doi:10.25346/S6/9BIIIH/6CQRH9', 'dataset_name': '20190502redraw', 'dataset_id': '21579', 'dataset_persistent_id': 'doi:10.25346/S6/9BIIIH', 'dataset_citation': 'KLEIN, BETH, 2020, "20190502redraw", https://doi.org/10.25346/S6/9BIIIH, UCLA Dataverse, V1'}, {'name': 'flat_out.list', 'type': 'file', 'url': 'https://dataverse.ucla.edu/api/access/datafile/21588', 'file_id': '21588', 'published_at': '2020-11-20T21:10:43Z', 'file_type': 'Plain Text', 'file_content_type': 'text/plain', 'size_in_bytes': 483, 'md5': '85b07f1a282ef260fc3901f943753c79', 'checksum': {'type': 'MD5', 'value': '85b07f1a282ef260fc3901f943753c79'}, 'file_persistent_id': 'doi:10.25346/S6/9BIIIH/ABJREL', 'dataset_name': '20190502redraw', 'dataset_id': '21579', 'dataset_persistent_id': 'doi:10.25346/S6/9BIIIH', 'dataset_citation': 'KLEIN, BETH, 2020, "20190502redraw", https://doi.org/10.25346/S6/9BIIIH, UCLA Dataverse, V1'}, {'name': 'flatwav_in.list', 'type': 'file', 'url': 'https://dataverse.ucla.edu/api/access/datafile/21589', 'file_id': '21589', 'published_at': '2020-11-20T21:10:43Z', 'file_type': 'Plain Text', 'file_content_type': 'text/plain', 'size_in_bytes': 192, 'md5': '9040938090326bcf3f5d1f285b981d89', 'checksum': {'type': 'MD5', 'value': '9040938090326bcf3f5d1f285b981d89'}, 'file_persistent_id': 'doi:10.25346/S6/9BIIIH/C5W5DM', 'dataset_name': '20190502redraw', 'dataset_id': '21579', 'dataset_persistent_id': 'doi:10.25346/S6/9BIIIH', 'dataset_citation': 'KLEIN, BETH, 2020, "20190502redraw", https://doi.org/10.25346/S6/9BIIIH, UCLA Dataverse, V1'}, {'name': 'flatwav_out.list', 'type': 'file', 'url': 'https://dataverse.ucla.edu/api/access/datafile/21582', 'file_id': '21582', 'published_at': '2020-11-20T21:10:43Z', 'file_type': 'Plain Text', 'file_content_type': 'text/plain', 'size_in_bytes': 224, 'md5': '560fb091bbca374096602b18eb118fcc', 'checksum': {'type': 'MD5', 'value': '560fb091bbca374096602b18eb118fcc'}, 'file_persistent_id': 'doi:10.25346/S6/9BIIIH/PADEKG', 'dataset_name': '20190502redraw', 'dataset_id': '21579', 'dataset_persistent_id': 'doi:10.25346/S6/9BIIIH', 'dataset_citation': 'KLEIN, BETH, 2020, "20190502redraw", https://doi.org/10.25346/S6/9BIIIH, UCLA Dataverse, V1'}, {'name': 'r1d.list', 'type': 'file', 'url': 'https://dataverse.ucla.edu/api/access/datafile/21583', 'file_id': '21583', 'published_at': '2020-11-20T21:10:43Z', 'file_type': 'Plain Text', 'file_content_type': 'text/plain', 'size_in_bytes': 209, 'md5': '16667d7094416a4782799e657a16bac3', 'checksum': {'type': 'MD5', 'value': '16667d7094416a4782799e657a16bac3'}, 'file_persistent_id': 'doi:10.25346/S6/9BIIIH/VTZP4B', 'dataset_name': '20190502redraw', 'dataset_id': '21579', 'dataset_persistent_id': 'doi:10.25346/S6/9BIIIH', 'dataset_citation': 'KLEIN, BETH, 2020, "20190502redraw", https://doi.org/10.25346/S6/9BIIIH, UCLA Dataverse, V1'}, {'name': 'S20190502S0061. ...
# === Page 10 ===
# start: 90  total: 5452
# https://dataverse.ucla.edu//api/search?q=*&start=100
# ...
# === Page 47 ===
# start: 460  total: 5452
# "Data Record 14.2 - Distribution of Eleotridae (sleepers) Cranial, Near-Cranial, and Postcranial Elements in the Paso de la Amada Assemblage",dataset,https://doi.org/10.25346/S6/OOUCAQ
# "Data Record 14.3 - Birds at Paso de la Amada Classified as Arboreal, Ground, Wading, and Swimming",dataset,https://doi.org/10.25346/S6/EKGCOC
# "Data Record 15.1 - Bone Needles",dataset,https://doi.org/10.25346/S6/38YEKN
# "Data Record 15.3 - Fishhooks",dataset,https://doi.org/10.25346/S6/JMH7UY
# "Data Record 15.2 - Pins and Awls",dataset,https://doi.org/10.25346/S6/JYGXZI
# https://dataverse.ucla.edu//api/search?q=*&start=470
# {'status': 'OK', 'data': {'q': '*', 'total_count': 5452, 'start': 470, 'spelling_alternatives': {}, 'items': [{'name': 'Paso Data Record 15.2.tab', 'type': 'file', 'url': 'https://dataverse.ucla.edu/api/access/datafile/23626', 'file_id': '23626', 'published_at': '2021-03-10T17:39:52Z', 'file_type': 'Tab-Delimited', 'file_content_type': 'text/tab-separated-values', 'size_in_bytes': 3931, 'md5': '208b341d7aa93fc21d5d30c76d18876b', 'checksum': {'type': 'MD5', 'value': '208b341d7aa93fc21d5d30c76d18876b'}, 'unf': 'UNF:6:ITPDQlOZlUBYJLNQTOdG3g==', 'file_persistent_id': 'doi:10.25346/S6/JYGXZI/GTWAOJ', 'dataset_name': 'Data Record 15.2 - Pins and Awls', 'dataset_id': '23625', 'dataset_persistent_id': 'doi:10.25346/S6/JYGXZI', 'dataset_citation': 'Wake, Thomas A.; Lesure, Richard G., 2021, "Data Record 15.2 - Pins and Awls", https://doi.org/10.25346/S6/JYGXZI, UCLA Dataverse, V1, UNF:6:ITPDQlOZlUBYJLNQTOdG3g== [fileUNF]'}, {'name': 'Data Record 20.1 - Data Used for Construction of Matrix for Multidimensional Scaling', 'type': 'dataset', 'url': 'https://doi.org/10.25346/S6/RGLDEM', 'global_id': 'doi:10.25346/S6/RGLDEM', 'description': 'Data used for the construction of a matrix for multidimensional scaling.', 'published_at': '2021-03-10T17:53:01Z', 'publisher': 'Paso de la Amada Dataverse', 'citationHtml': 'Lesure, Richard G., 2021, "Data Record 20.1 - Data Used for Construction of Matrix for Multidimensional Scaling", <a href="https://doi.org/10.25346/S6/RGLDEM" target="_blank">https://doi.org/10.25346/S6/RGLDEM</a>, UCLA Dataverse, V1, UNF:6:337h6gB3DBznUDU3B/ofaA== [fileUNF]', 'identifier_of_dataverse': 'paso-de-la-amada', 'name_of_dataverse': 'Paso de la Amada Dataverse', 'citation': 'Lesure, Richard G., 2021, "Data Record 20.1 - Data Used for Construction of Matrix for Multidimensional Scaling", https://doi.org/10.25346/S6/RGLDEM, UCLA Dataverse, V1, UNF:6:337h6gB3DBznUDU3B/ofaA== [fileUNF]', 'storageIdentifier': 's3://10.25346/S6/RGLDEM', 'subjects': ['Arts and Humanities'], 'fileCount': 1, 'versionId': 1289, 'versionState': 'RELEASED', 'majorVersion': 1, 'minorVersion': 0, 'createdAt': '2021-03-04T18:32:00Z', 'updatedAt': '2021-03-10T17:53:01Z', 'contacts': [{'name': 'BRIN, DEIDRE', 'affiliation': 'University of California, Los Angeles'}], 'publications': [{'citation': 'Lesure, Richard G., 2021. Paso de la Amada: An Early Mesoamerican Ceremonial Center. Monumenta Archaeologica, 45. Los Angeles: Cotsen Institute of Archaeology Press.'}], 'authors': ['Lesure, Richard G.']}, {'name': 'Paso Data Record 20.1.tab', 'type': 'file', 'url': 'https://dataverse.ucla.edu/api/access/datafile/23632', 'file_id': '23632', 'published_at': '2021-03-10T17:53:01Z', 'file_type': 'Tab-Delimited', 'file_content_type': 'text/tab-separated-values', 'size_in_bytes': 2390, 'md5': '6d412bcaa161319c91bff820fb5aadbf', 'checksum': {'type': 'MD5', 'value': '6d412bcaa161319c91bff820fb5aadbf'}, 'unf': 'UNF:6:337h6gB3DBznUDU3B/ofaA==', 'file_persistent_id': 'doi:10.25346/S6/RGLDEM/4791FV', 'dataset_name': 'Data Record 20.1 - Data Used for Construction of Matrix for Multidimensional Scaling', 'dataset_id': '23631', 'dataset_persistent_id': 'doi:10.25346/S6/RGLDEM', 'dataset_citation': 'Lesure, Richard G., 2021, "Data Record 20.1 - Data Used for Construction of Matrix for Multidimensional Scaling", https://doi.org/10.25346/S6/RGLDEM, UCLA Dataverse, V1, UNF:6:337h6gB3DBznUDU3B/ofaA== [fileUNF]'}, {'name': 'Data Record 20.2 - Raw Data Used to Construct Tables 20.5 and 20.6', 'type': 'dataset', 'url': 'https://doi.org/10.25346/S6/2Z9CAB', 'global_id': 'doi:10.25346/S6/2Z9CAB', 'description': 'Raw data used to construct Tables 20.5 and 20.6 in the publication.', 'published_at': '2021-03-10T17:56:39Z', 'publisher': 'Paso de la Amada Dataverse', 'citationHtml': 'Lesure, Richard G., 2021, "Data Record 20.2 - Raw Data Used to Construct Tables 20.5 and 20.6", <a href="https://doi.org/10.25346/S6/2Z9CAB" target="_blank">https://doi.org/10.25346/S6/2Z9CAB</a>, UCLA Dataverse ...
# === Page 48 ===
# start: 470  total: 5452
# "Data Record 20.1 - Data Used for Construction of Matrix for Multidimensional Scaling",dataset,https://doi.org/10.25346/S6/RGLDEM
# "Data Record 20.2 - Raw Data Used to Construct Tables 20.5 and 20.6",dataset,https://doi.org/10.25346/S6/2Z9CAB
# "Data Record 17.1 - Distribution of Clay Ear Ornament Fragments by Provenience",dataset,https://doi.org/10.25346/S6/I9ELTO
# "Data Record 21.1 - List of Sherds Analyzed for Residues",dataset,https://doi.org/10.25346/S6/SP5RNY
# "Data Record A2 - Ceramics Analyzed to Level A",dataset,https://doi.org/10.25346/S6/VNLFFE
# https://dataverse.ucla.edu//api/search?q=*&start=480
# {'status': 'OK', 'data': {'q': '*', 'total_count': 5452, 'start': 480, 'spelling_alternatives': {}, 'items': [{'name': 'Paso Data Record A2 final.tab', 'type': 'file', 'url': 'https://dataverse.ucla.edu/api/access/datafile/23641', 'file_id': '23641', 'published_at': '2021-03-10T18:06:28Z', 'file_type': 'Tab-Delimited', 'file_content_type': 'text/tab-separated-values', 'size_in_bytes': 2267744, 'md5': '8d41febc02b8058860ed56b4c5b1105e', 'checksum': {'type': 'MD5', 'value': '8d41febc02b8058860ed56b4c5b1105e'}, 'unf': 'UNF:6:zS07zEAy2F1jbCW44UsOmw==', 'file_persistent_id': 'doi:10.25346/S6/VNLFFE/9EBVQU', 'dataset_name': 'Data Record A2 - Ceramics Analyzed to Level A', 'dataset_id': '23640', 'dataset_persistent_id': 'doi:10.25346/S6/VNLFFE', 'dataset_citation': 'Lesure, Richard G., 2021, "Data Record A2 - Ceramics Analyzed to Level A", https://doi.org/10.25346/S6/VNLFFE, UCLA Dataverse, V1, UNF:6:zS07zEAy2F1jbCW44UsOmw== [fileUNF]'}, {'name': 'Data Record A3 - Ceramics Analyzed to Levels A and B', 'type': 'dataset', 'url': 'https://doi.org/10.25346/S6/TBBDFA', 'global_id': 'doi:10.25346/S6/TBBDFA', 'description': 'Table of ceramics analyzed to Levels A and B.', 'published_at': '2021-03-10T18:10:36Z', 'publisher': 'Paso de la Amada Dataverse', 'citationHtml': 'Lesure, Richard G., 2021, "Data Record A3 - Ceramics Analyzed to Levels A and B", <a href="https://doi.org/10.25346/S6/TBBDFA" target="_blank">https://doi.org/10.25346/S6/TBBDFA</a>, UCLA Dataverse, V1, UNF:6:ZnbApJPmdysC+wE7T8pNFg== [fileUNF]', 'identifier_of_dataverse': 'paso-de-la-amada', 'name_of_dataverse': 'Paso de la Amada Dataverse', 'citation': 'Lesure, Richard G., 2021, "Data Record A3 - Ceramics Analyzed to Levels A and B", https://doi.org/10.25346/S6/TBBDFA, UCLA Dataverse, V1, UNF:6:ZnbApJPmdysC+wE7T8pNFg== [fileUNF]', 'storageIdentifier': 's3://10.25346/S6/TBBDFA', 'subjects': ['Arts and Humanities'], 'fileCount': 1, 'versionId': 1294, 'versionState': 'RELEASED', 'majorVersion': 1, 'minorVersion': 0, 'createdAt': '2021-03-04T19:15:49Z', 'updatedAt': '2021-03-10T18:10:36Z', 'contacts': [{'name': 'BRIN, DEIDRE', 'affiliation': 'University of California, Los Angeles'}], 'publications': [{'citation': 'Lesure, Richard G., 2021. Paso de la Amada: An Early Mesoamerican Ceremonial Center. Monumenta Archaeologica, 45. Los Angeles: Cotsen Institute of Archaeology Press.'}], 'authors': ['Lesure, Richard G.']}, {'name': 'Paso Data Record A3 final.tab', 'type': 'file', 'url': 'https://dataverse.ucla.edu/api/access/datafile/23644', 'file_id': '23644', 'published_at': '2021-03-10T18:10:36Z', 'file_type': 'Tab-Delimited', 'file_content_type': 'text/tab-separated-values', 'size_in_bytes': 1110650, 'md5': 'bb7f57b056a8e94c42326fef42c7305a', 'checksum': {'type': 'MD5', 'value': 'bb7f57b056a8e94c42326fef42c7305a'}, 'unf': 'UNF:6:ZnbApJPmdysC+wE7T8pNFg==', 'file_persistent_id': 'doi:10.25346/S6/TBBDFA/3QCE5C', 'dataset_name': 'Data Record A3 - Ceramics Analyzed to Levels A and B', 'dataset_id': '23642', 'dataset_persistent_id': 'doi:10.25346/S6/TBBDFA', 'dataset_citation': 'Lesure, Richard G., 2021, "Data Record A3 - Ceramics Analyzed to Levels A and B", https://doi.org/10.25346/S6/TBBDFA, UCLA Dataverse, V1, UNF:6:ZnbApJPmdysC+wE7T8pNFg== [fileUNF]'}, {'name': 'Data Record A5 - Obsidian Source and Use Wear Data', 'type': 'dataset', 'url': 'https://doi.org/10.25346/S6/YAD2PC', 'global_id': 'doi:10.25346/S6/YAD2PC', 'description': 'Obsidian sources and use wear data.', 'published_at': '2021-03-10T18:17:25Z', 'publisher': 'Paso de la Amada Dataverse', 'citationHtml': 'Lesure, Richard G., 2021, "Data Record A5 - Obsidian Source and Use Wear Data", <a href="https://doi.org/10.25346/S6/YAD2PC" target="_blank">https://doi.org/10.25346/S6/YAD2PC</a>, UCLA Dataverse, V1, UNF:6:0qT3tqiS+AvOJUn28VdxjQ== [fileUNF]', 'identifier_of_dataverse': 'paso-de-la-amada', 'name_of_dataverse': 'Paso de la Amada Dataverse', 'citation': 'Lesure, Richard G., 2021, "Data Record A5 - Obsidian Source and Use  ...
# === Page 49 ===
# start: 480  total: 5452
# "Data Record A3 - Ceramics Analyzed to Levels A and B",dataset,https://doi.org/10.25346/S6/TBBDFA
# "Data Record A5 - Obsidian Source and Use Wear Data",dataset,https://doi.org/10.25346/S6/YAD2PC
# "Data Record A4 - Ceramics Analyzed to Levels A, B, and C",dataset,https://doi.org/10.25346/S6/YT63X4
# "Introduction to QGIS",dataset,https://doi.org/10.25346/S6/LOZHYJ
# https://dataverse.ucla.edu//api/search?q=*&start=490
# {'status': 'OK', 'data': {'q': '*', 'total_count': 5452, 'start': 490, 'spelling_alternatives': {}, 'items': [{'name': 'GroceryStore_sp.zip', 'type': 'file', 'url': 'https://dataverse.ucla.edu/api/access/datafile/21055', 'file_id': '21055', 'published_at': '2020-08-21T17:11:01Z', 'file_type': 'Shapefile as ZIP Archive', 'file_content_type': 'application/zipped-shapefile', 'size_in_bytes': 132968, 'md5': '621106020a745d12072e2504c424d464', 'checksum': {'type': 'MD5', 'value': '621106020a745d12072e2504c424d464'}, 'file_persistent_id': 'doi:10.25346/S6/LOZHYJ/CESGUT', 'dataset_name': 'Introduction to QGIS', 'dataset_id': '21046', 'dataset_persistent_id': 'doi:10.25346/S6/LOZHYJ', 'dataset_citation': 'YAO, ZHIYUAN; Jamie Jamison; Leigh Phan, 2020, "Introduction to QGIS", https://doi.org/10.25346/S6/LOZHYJ, UCLA Dataverse, DRAFT VERSION, UNF:6:a3H2xuIO/lRROs/qMOfGgw== [fileUNF]'}, {'name': 'Introduction to QGIS.mp4', 'type': 'file', 'url': 'https://dataverse.ucla.edu/api/access/datafile/21058', 'file_id': '21058', 'published_at': '2020-08-21T17:11:01Z', 'file_type': 'MPEG-4 Video', 'file_content_type': 'video/mp4', 'size_in_bytes': 302508743, 'md5': '9a42814c7528cc1a70f74310b37e7c93', 'checksum': {'type': 'MD5', 'value': '9a42814c7528cc1a70f74310b37e7c93'}, 'file_persistent_id': 'doi:10.25346/S6/LOZHYJ/MBFTU9', 'dataset_name': 'Introduction to QGIS', 'dataset_id': '21046', 'dataset_persistent_id': 'doi:10.25346/S6/LOZHYJ', 'dataset_citation': 'YAO, ZHIYUAN; Jamie Jamison; Leigh Phan, 2020, "Introduction to QGIS", https://doi.org/10.25346/S6/LOZHYJ, UCLA Dataverse, DRAFT VERSION, UNF:6:a3H2xuIO/lRROs/qMOfGgw== [fileUNF]'}, {'name': 'Introduction to QGIS.pptx', 'type': 'file', 'url': 'https://dataverse.ucla.edu/api/access/datafile/21057', 'file_id': '21057', 'published_at': '2020-08-21T17:11:01Z', 'file_type': 'MS Powerpoint', 'file_content_type': 'application/vnd.openxmlformats-officedocument.presentationml.presentation', 'size_in_bytes': 7792220, 'md5': '22eb8995692676586b132dd0385aeafd', 'checksum': {'type': 'MD5', 'value': '22eb8995692676586b132dd0385aeafd'}, 'file_persistent_id': 'doi:10.25346/S6/LOZHYJ/Z4ZOYT', 'dataset_name': 'Introduction to QGIS', 'dataset_id': '21046', 'dataset_persistent_id': 'doi:10.25346/S6/LOZHYJ', 'dataset_citation': 'YAO, ZHIYUAN; Jamie Jamison; Leigh Phan, 2020, "Introduction to QGIS", https://doi.org/10.25346/S6/LOZHYJ, UCLA Dataverse, DRAFT VERSION, UNF:6:a3H2xuIO/lRROs/qMOfGgw== [fileUNF]'}, {'name': 'Neighborhood_sp.zip', 'type': 'file', 'url': 'https://dataverse.ucla.edu/api/access/datafile/21053', 'file_id': '21053', 'published_at': '2020-08-21T17:11:01Z', 'file_type': 'Shapefile as ZIP Archive', 'file_content_type': 'application/zipped-shapefile', 'size_in_bytes': 258186, 'md5': 'a3fca61a82b4cab287bab38148e8ce72', 'checksum': {'type': 'MD5', 'value': 'a3fca61a82b4cab287bab38148e8ce72'}, 'file_persistent_id': 'doi:10.25346/S6/LOZHYJ/G6GRLR', 'dataset_name': 'Introduction to QGIS', 'dataset_id': '21046', 'dataset_persistent_id': 'doi:10.25346/S6/LOZHYJ', 'dataset_citation': 'YAO, ZHIYUAN; Jamie Jamison; Leigh Phan, 2020, "Introduction to QGIS", https://doi.org/10.25346/S6/LOZHYJ, UCLA Dataverse, DRAFT VERSION, UNF:6:a3H2xuIO/lRROs/qMOfGgw== [fileUNF]'}, {'name': '106右派处理', 'type': 'dataset', 'url': 'https://doi.org/10.25346/S6/P64ZOJ', 'global_id': 'doi:10.25346/S6/P64ZOJ', 'description': 'Test preview function, view-pdf on EAL documents', 'published_at': '2020-01-11T00:26:41Z', 'publisher': 'UCLA Library Materials', 'citationHtml': 'JAMISON, JINA, 2020, "106&#21491;&#27966;&#22788;&#29702;", <a href="https://doi.org/10.25346/S6/P64ZOJ" target="_blank">https://doi.org/10.25346/S6/P64ZOJ</a>, UCLA Dataverse, V2', 'identifier_of_dataverse': 'ucla-library-restricted', 'name_of_dataverse': 'UCLA Library Materials', 'citation': 'JAMISON, JINA, 2020, "106右派处理", https://doi.org/10.25346/S6/P64ZOJ, UCLA Dataverse, V2', 'storageIdentifier': 's3://10.25346/S6/P64ZOJ', 'subjects': ['Other'], 'fileCount': 1 ...
# === Page 50 ===
# start: 490  total: 5452
# "106右派处理",dataset,https://doi.org/10.25346/S6/P64ZOJ
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# <ipython-input-4-c3498650f557> in <module>
#      37                 line=("\"" + i['name'] + "\"" + "," + i['type']+ "," + i['url'])
#      38                 print(line)
# ---> 39                 outfile.write(line)
#      40                 outfile.write("\n")
#      41
#
# ~\anaconda3\lib\encodings\cp1252.py in encode(self, input, final)
#      17 class IncrementalEncoder(codecs.IncrementalEncoder):
#      18     def encode(self, input, final=False):
# ---> 19         return codecs.charmap_encode(input,self.errors,encoding_table)[0]
#      20
#      21 class IncrementalDecoder(codecs.IncrementalDecoder):
#
# UnicodeEncodeError: 'charmap' codec can't encode characters in position 4-7: character maps to <undefined>
